# %%
import csv
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('data.csv', parse_dates=['Intake-DateTime', 'Outcome-DateTime'])
data.dtypes
# Out:
# AnimalID                         object
# ID                               object
# Breed                            object
# Color                            object
# Gender                           object
# Name                             object
# Intake-DateTime          datetime64[ns]
# Intake-Type                      object
# Intake-Condition                 object
# Intake-Age(days)                  int64
# Date-Of-Birth                    object
# Outcome-DateTime         datetime64[ns]
# Outcome-Type                     object
# Outcome-Subtype                  object
# Outcome-Age(days)                 int64
# Age                              object
# IsAdopted                          bool
# Category                         object
# Intelligence-Ranking              int64
# Intelligence-Category            object
# Size-Category                    object
# Longevity                       float64
# Total-Cost($)                     int64
# Purchase-Cost($)                  int64
# Food-Cost($)                      int64
# Cost-Category                    object
# dtype: object

# %%
adoption = data[data['IsAdopted'] == True]
adoption
# Out:
#       AnimalID       ID                   Breed     Color  Gender       Name  \
# 7      A200922  A200922               Dachshund     Black    Male     Carlos
# 13     A226069  A226069      Labrador Retriever     Sable    Male      Cedar
# 28     A274546  A274546                 Pointer  Tricolor  Female     Sophie
# 32     A281542  A281542      Labrador Retriever     Black    Male     George
# 45     A302820  A302820         German Shepherd     Brown  Female   *Ladybug
# ...        ...      ...                     ...       ...     ...        ...
# 85780  A893211  A893211               Chow Chow     Cream  Female  Chowbella
# 85782  A893223  A893223                 Maltese     White    Male    Unknown
# 85784  A893286  A893286                     Pug      Fawn  Female    Unknown
# 85785  A893287  A893287                     Pug      Fawn  Female    Brisket
# 85786  A893319  A893319  Parson Russell Terrier  Tricolor  Female      *Spot
#
#           Intake-DateTime      Intake-Type Intake-Condition  Intake-Age(days)  \
# 7     2013-10-03 15:47:00  Owner Surrender           Normal             12190
# 13    2015-10-06 12:29:00            Stray           Normal             11825
# 28    2013-11-13 18:16:00            Stray           Normal              1365
# 32    2013-12-23 13:23:00  Owner Surrender           Normal              1730
# 45    2014-02-27 14:17:00  Owner Surrender           Normal              3650
# ...                   ...              ...              ...               ...
# 85780 2023-11-17 10:13:00  Owner Surrender           Normal              1365
# 85782 2023-11-17 12:13:00            Stray           Normal                60
# 85784 2023-11-18 14:06:00            Stray           Normal                30
# 85785 2023-11-18 14:06:00            Stray           Normal                30
# 85786 2023-11-19 12:42:00  Owner Surrender           Normal               240
#
#        ... IsAdopted      Category Intelligence-Ranking Intelligence-Category  \
# 7      ...      True         Hound                   49               Average
# 13     ...      True      Sporting                    7             Brightest
# 28     ...      True      Sporting                   43               Average
# 32     ...      True      Sporting                    7             Brightest
# 45     ...      True       Herding                    3             Brightest
# ...    ...       ...           ...                  ...                   ...
# 85780  ...      True  Non-Sporting                   77                   Low
# 85782  ...      True           Toy                   59                  Fair
# 85784  ...      True           Toy                   57                  Fair
# 85785  ...      True           Toy                   57                  Fair
# 85786  ...      True       Terrier                   44               Average
#
#        Size-Category Longevity  Total-Cost($) Purchase-Cost($)  Food-Cost($)  \
# 7              Small     12.63          17350              423          3517
# 13            Medium     12.04          18422              810          4819
# 28             Large     12.42          21049              294          7565
# 32            Medium     12.04          18422              810          4819
# 45             Large      9.73          15091              820          3895
# ...              ...       ...            ...              ...           ...
# 85780         Medium      9.01          13745              515          3606
# 85782          Small     12.25          16073              650          2410
# 85784         Medium     11.00          15421              469          3246
# 85785         Medium     11.00          15421              469          3246
# 85786          Small     11.48          18078              528          3809
#
#       Cost-Category
# 7             Saver
# 13           Budget
# 28         High-End
# 32           Budget
# 45            Saver
# ...             ...
# 85780     Mid-Price
# 85782         Saver
# 85784         Saver
# 85785         Saver
# 85786        Budget
#
# [42234 rows x 26 columns]

# %% [markdown]
# # Adoption Trends

# %% [markdown]
# ### Popular months

# %%
# Extract month from outcome-datetime
months = data['Outcome-DateTime'].dt.month.value_counts().reset_index()
months.columns = ['Month', 'Counts']
adoption_months = adoption['Outcome-DateTime'].dt.month.value_counts().reset_index()
adoption_months.columns = ['Month', 'Counts']

months = months.sort_values(by=['Month']).reset_index(drop=True)
adoption_months = adoption_months.sort_values(by=['Month']).reset_index(drop=True)

ax = months.plot(x='Month', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5) 
adoption_months.plot(ax=ax, x='Month', y='Counts', kind='bar', legend=True, color='red', label='Adoption',alpha=0.5)
plt.title('Distribution of Adoption Month')
plt.show()

# %%
adoption_months.plot(x='Month', y='Counts', kind='pie', autopct='%1.1f%%', labels=adoption_months['Month'], legend=False)
plt.title('Pie Chart of Adoption Month Distribution')
plt.show()

# %%
months['Adopt-Rate'] = adoption_months['Counts'] / months['Counts']

fig, ax = plt.subplots()
ax.plot(months['Month'], months['Adopt-Rate'])
plt.xlabel('Month')
plt.ylabel('Adopt Rate')
plt.title('Adoption Rate of Months')
plt.show()

# %% [markdown]
# ### Adoption yearly trend

# %%
# Extract month from outcome-datetime
years = data['Outcome-DateTime'].dt.year.value_counts().reset_index()
years.columns = ['Year', 'Counts']
adoption_years = adoption['Outcome-DateTime'].dt.year.value_counts().reset_index()
adoption_years.columns = ['Year', 'Counts']

years = years.sort_values(by=['Year']).reset_index(drop=True)
adoption_years = adoption_years.sort_values(by=['Year']).reset_index(drop=True)

ax = years.plot(x='Year', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5) 
adoption_years.plot(ax=ax, x='Year', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Adoption Year')
plt.show()

# %%
years['Adopt-Rate'] = adoption_years['Counts'] / years['Counts']

fig, ax = plt.subplots()
ax.plot(years['Year'], years['Adopt-Rate'])
plt.xlabel('Year')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Adoption breed trend

# %%
def plotBreed(breed_name):
    ast = data[data['Breed'] == breed_name]
    ast = ast['Outcome-DateTime'].dt.year.value_counts().reset_index()
    ast = ast.sort_values(by=['Outcome-DateTime']).reset_index(drop=True)
    
    adoption_ast = adoption[adoption['Breed'] == breed_name]
    adoption_ast = adoption_ast['Outcome-DateTime'].dt.year.value_counts().reset_index()
    adoption_ast = adoption_ast.sort_values(by=['Outcome-DateTime']).reset_index(drop=True)

    plt.plot(ast['Outcome-DateTime'], adoption_ast['count']/ast['count'])

# %%
def compareBreeds(breeds):
    for breed_name in breeds:
        plotBreed(breed_name)
        plt.legend(breeds)
        plt.xlabel('Year')
        plt.ylabel('Adopt Rate')

# %%
def plotBreedProp(breed_name):
    ast = data[data['Breed'] == breed_name]
    ast = ast['Outcome-DateTime'].dt.year.value_counts().reset_index()
    ast = ast.sort_values(by=['Outcome-DateTime']).reset_index(drop=True)
    
    adoption_count = adoption['Outcome-DateTime'].dt.year.value_counts().reset_index()
    adoption_count = adoption_count.sort_values(by=['Outcome-DateTime']).reset_index(drop=True)

    plt.plot(ast['Outcome-DateTime'], ast['count']/adoption_count['count'])

# %%
def compareBreedProp(breeds):
    for breed_name in breeds:
        plotBreedProp(breed_name)
        plt.legend(breeds)
        plt.xlabel('Year')
        plt.ylabel('Breed Proportion')

# %%
top5 = data['Breed'].value_counts().nlargest(5).reset_index()
top5
# Out:
#                             Breed  count
# 0  American Staffordshire Terrier  13512
# 1              Labrador Retriever  12109
# 2                       Chihuahua  10222
# 3                 German Shepherd   6336
# 4           Australian Cattle Dog   3646

# %%
compareBreeds(['American Staffordshire Terrier', 'Labrador Retriever', 'Chihuahua', 'German Shepherd', 
               'Australian Cattle Dog'])

# %%
compareBreedProp(['American Staffordshire Terrier', 'Labrador Retriever', 'Chihuahua', 'German Shepherd', 
               'Australian Cattle Dog'])

# %% [markdown]
# # Adoption Factors

# %% [markdown]
# ## Use Pandas & Numpy & Matplotlib to draw diagrams and analyze adoption factors

# %% [markdown]
# ### Breed

# %%
top10_breeds = data['Breed'].value_counts().nlargest(10).reset_index(name='Counts')
top10_breeds
# Out:
#                             Breed  Counts
# 0  American Staffordshire Terrier   13512
# 1              Labrador Retriever   12109
# 2                       Chihuahua   10222
# 3                 German Shepherd    6336
# 4           Australian Cattle Dog    3646
# 5                       Dachshund    2448
# 6                  Siberian Husky    1837
# 7                           Boxer    1754
# 8                   Border Collie    1661
# 9                          Poodle    1581

# %%
adoption_top10_breeds = adoption['Breed'].value_counts().nlargest(10).reset_index(name='Counts')
adoption_top10_breeds
# Out:
#                             Breed  Counts
# 0              Labrador Retriever    6630
# 1  American Staffordshire Terrier    5907
# 2                       Chihuahua    4948
# 3                 German Shepherd    3593
# 4           Australian Cattle Dog    2191
# 5                       Dachshund    1247
# 6                  Siberian Husky     973
# 7                   Border Collie     957
# 8                           Boxer     875
# 9      American English Coonhound     721

# %%
# Total vs Adoption - Breeds distribution
p = ['American Staffordshire Terrier', 'Labrador Retriever', 'Chihuahua', 'German Shepherd', 
    'Australian Cattle Dog', 'Dachshund', 'Siberian Husky', 'Boxer', 'Border Collie', 'Poodle',  
     'American English Coonhound']

top_breeds = data[data['Breed'].isin(p)]['Breed'].value_counts().reset_index()
top_breeds = top_breeds.sort_values(by=['Breed']).reset_index(drop=True)

adoption_top_breeds = adoption[adoption['Breed'].isin(p)]['Breed'].value_counts().reset_index()
adoption_top_breeds = adoption_top_breeds.sort_values(by=['Breed']).reset_index(drop=True)

ax = top_breeds.plot(x='Breed', y='count', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_top_breeds.plot(ax=ax, x='Breed', y='count', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)

plt.title('Distribution of Breeds')
plt.show()

# %%
# Adoption rate
top_breeds['Adopt-Rate'] = adoption_top_breeds['count'] / top_breeds['count']

fig, ax = plt.subplots()
ax.plot(top_breeds['Breed'], top_breeds['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Breed')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Category

# %%
# Total vs Adoption - Category distribution

ax = data['Category'].value_counts().plot(y='count', kind='bar', legend=True, label='Total', alpha=0.5)
adoption['Category'].value_counts().plot(ax=ax, y='count', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Category')
plt.show()

# %% [markdown]
# ### Gender

# %%
# Total vs Adoption - Gender distribution

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))
axes[0].set_title("Gender Distribution", size=12)
axes[1].set_title("Adoption Gender Distribution", size=12)
axes[0].pie(data['Gender'].value_counts(), labels=['Male', 'Female'], autopct='%.0f%%')
axes[1].pie(adoption['Gender'].value_counts(), labels=['Male', 'Female'], autopct='%.0f%%')
plt.show()

# %% [markdown]
# ### Age

# %%
# Total vs Adoption - Age distribution

age = data['Age'].value_counts().reset_index(name='Counts')
adoption_age = adoption['Age'].value_counts().reset_index(name='Counts')

# Sort from baby to senior
a_labels = ['Baby','Young','Adult','Senior']
a_orders = [0,1,2,3]
a_map = dict(zip(a_labels, a_orders))
age['Order'] = age['Age'].map(a_map)
adoption_age['Order'] = adoption_age['Age'].map(a_map)
age.sort_values(by=['Order'], inplace=True)
adoption_age.sort_values(by=['Order'], inplace=True)
# plot
ax = age.plot(x='Age', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_age.plot(ax=ax, x='Age', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Age')
plt.show()

# %%
# Adoption rate
age['Adopt-Rate'] = adoption_age['Counts'] / age['Counts']

fig, ax = plt.subplots()
ax.plot(age['Age'], age['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Age')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Color

# %%
# Total vs Adoption - Color distribution

top10_color = data['Color'].value_counts().nlargest(10).reset_index(name='Counts')
adoption_top10_color = adoption['Color'].value_counts().nlargest(10).reset_index(name='Counts')

ax = top10_color.plot(x='Color', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_top10_color.plot(ax=ax, x='Color', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Color')
plt.show()

# %%
# Adoption rate
top10_color['Adopt-Rate'] = adoption_top10_color['Counts'] / top10_color['Counts']

fig, ax = plt.subplots()
ax.plot(top10_color['Color'], top10_color['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Color')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Intelligence

# %%
# Total vs Adoption - Intellogence distribution

intell = data['Intelligence-Category'].value_counts().reset_index(name='Counts')
adoption_intell = adoption['Intelligence-Category'].value_counts().reset_index(name='Counts')

# Sort from brightest to low
i_labels = ['Brightest','Excellent','Above-Average','Average','Fair','Low' ]
i_orders = [0,1,2,3,4,5]
i_map = dict(zip(i_labels, i_orders))
intell['Order'] = intell['Intelligence-Category'].map(i_map)
adoption_intell['Order'] = adoption_intell['Intelligence-Category'].map(i_map)
intell.sort_values(by=['Order'], inplace=True)
adoption_intell.sort_values(by=['Order'], inplace=True)
# plot
ax = intell.plot(x='Intelligence-Category', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_intell.plot(ax=ax, x='Intelligence-Category', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Intelligence')
plt.show()

# %%
# Adoption rate
intell['Adopt-Rate'] = adoption_intell['Counts'] / intell['Counts']

fig, ax = plt.subplots()
ax.plot(intell['Intelligence-Category'], intell['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Intelligence-Category')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Size

# %%
# Total vs Adoption - Size distribution

size = data['Size-Category'].value_counts().reset_index(name='Counts')
adoption_size = adoption['Size-Category'].value_counts().reset_index(name='Counts')

# Sort from samll to large
s_labels = ['Small','Medium','Large']
s_orders = [0,1,2]
s_map = dict(zip(s_labels, s_orders))
size['Order'] = size['Size-Category'].map(s_map)
adoption_size['Order'] = adoption_size['Size-Category'].map(s_map)
size.sort_values(by=['Order'], inplace=True)
adoption_size.sort_values(by=['Order'], inplace=True)
# plot

ax = size.plot(x='Size-Category', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_size.plot(ax=ax, x='Size-Category', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Dsitribution of Size')
plt.show()

# %%
# Adoption rate
size['Adopt-Rate'] = adoption_size['Counts'] / size['Counts']

fig, ax = plt.subplots()
ax.plot(size['Size-Category'], size['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Size-Category')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Cost

# %%
# Total cost range

plt.boxplot(data['Total-Cost($)'])
plt.title('Total Cost Boxplot')
plt.show()

# %%
# Total vs Adoption - Cost distribution

cost = data['Cost-Category'].value_counts().reset_index(name='Counts')
adoption_cost = adoption['Cost-Category'].value_counts().reset_index(name='Counts')

# Sort from saver to high-end
c_labels = ['Saver','Budget','Mid-Price','High-End']
c_orders = [0,1,2,3]
c_map = dict(zip(c_labels, c_orders))
cost['Order'] = cost['Cost-Category'].map(c_map)
adoption_cost['Order'] = adoption_cost['Cost-Category'].map(c_map)
cost.sort_values(by=['Order'], inplace=True)
adoption_cost.sort_values(by=['Order'], inplace=True)
# plot

ax = cost.plot(x='Cost-Category', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_cost.plot(ax=ax, x='Cost-Category', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Cost')
plt.show()

# %%
# Adoption rate
cost['Adopt-Rate'] = adoption_cost['Counts'] / cost['Counts']

fig, ax = plt.subplots()
ax.plot(cost['Cost-Category'], cost['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Cost-Category')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ### Intake-Type

# %%
# Total vs Adoption - Intake-Type distribution
intake = data['Intake-Type'].value_counts().reset_index(name='Counts')
adoption_intake = adoption['Intake-Type'].value_counts().reset_index(name='Counts')

ax = intake.plot(x='Intake-Type', y='Counts', kind='bar', legend=True, label='Total', alpha=0.5)
adoption_intake.plot(ax=ax, x='Intake-Type', y='Counts', kind='bar', legend=True, color='red', label='Adoption', alpha=0.5)
plt.title('Distribution of Intake-Type')
plt.show()

# %%
# Adoption rate
intake['Adopt-Rate'] = adoption_intake['Counts'] / intake['Counts']

fig, ax = plt.subplots()
ax.plot(intake['Intake-Type'], intake['Adopt-Rate'])
plt.xticks(rotation='vertical')
plt.xlabel('Intake-Type')
plt.ylabel('Adopt Rate')
plt.show()

# %% [markdown]
# ## Use Apriori algorithm to compute and extract association rules to analyse adoption factors

# %%
# (c) 2016 Everaldo Aguiar & Reid Johnson
#
# Modified from:
# Marcel Caraciolo (https://gist.github.com/marcelcaraciolo/1423287)
#
# Functions to compute and extract association rules from a given frequent itemset 
# generated by the Apriori algorithm.
#
# The Apriori algorithm is defined by Agrawal and Srikant in:
# Fast algorithms for mining association rules
# Proc. 20th int. conf. very large data bases, VLDB. Vol. 1215. 1994

def load_dataset(filename):
    '''Loads an example of market basket transactions from a provided csv file.

    Returns: A list (database) of lists (transactions). Each element of a transaction is 
    an item.
    '''

    with open(filename,'r') as dest_f:
        data_iter = csv.reader(dest_f, delimiter = ',', quotechar = '"')
        data = [data for data in data_iter]
        data_array = np.asarray(data, dtype=object)
        
    return data_array

def apriori(dataset, min_support=0.5, verbose=False):
    """Implements the Apriori algorithm.

    The Apriori algorithm will iteratively generate new candidate 
    k-itemsets using the frequent (k-1)-itemsets found in the previous 
    iteration.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate 
        candidate itemsets.

    min_support : float
        The minimum support threshold. Defaults to 0.5.

    Returns
    -------
    F : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.

    References
    ----------
    .. [1] R. Agrawal, R. Srikant, "Fast Algorithms for Mining Association 
           Rules", 1994.

    """
    C1 = create_candidates(dataset)
    D = list(map(set, dataset))
    F1, support_data = support_prune(D, C1, min_support, verbose=False) # prune candidate 1-itemsets
    F = [F1] # list of frequent itemsets; initialized to frequent 1-itemsets
    k = 2 # the itemset cardinality
    while (len(F[k - 2]) > 0):
        Ck = apriori_gen(F[k-2], k) # generate candidate itemsets
        Fk, supK = support_prune(D, Ck, min_support) # prune candidate itemsets
        support_data.update(supK) # update the support counts to reflect pruning
        F.append(Fk) # add the pruned candidate itemsets to the list of frequent itemsets
        k += 1

    if verbose:
        # Print a list of all the frequent itemsets.
        for kset in F:
            for item in kset:
                print("" \
                    + "{" \
                    + "".join(str(i) + ", " for i in iter(item)).rstrip(', ') \
                    + "}" \
                    + ":  sup = " + str(round(support_data[item], 3)))

    return F, support_data

def create_candidates(dataset, verbose=False):
    """Creates a list of candidate 1-itemsets from a list of transactions.

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    Returns
    -------
    The list of candidate itemsets (c1) passed as a frozenset (a set that is 
    immutable and hashable).
    """
    c1 = [] # list of all items in the database of transactions
    for transaction in dataset:
        for item in transaction:
            if not [item] in c1:
                c1.append([item])
    c1.sort()

    if verbose:
        # Print a list of all the candidate items.
        print("" \
            + "{" \
            + "".join(str(i[0]) + ", " for i in iter(c1)).rstrip(', ') \
            + "}")

    # Map c1 to a frozenset because it will be the key of a dictionary.
    return list(map(frozenset, c1))

def support_prune(dataset, candidates, min_support, verbose=False):
    """Returns all candidate itemsets that meet a minimum support threshold.

    By the apriori principle, if an itemset is frequent, then all of its 
    subsets must also be frequent. As a result, we can perform support-based 
    pruning to systematically control the exponential growth of candidate 
    itemsets. Thus, itemsets that do not meet the minimum support level are 
    pruned from the input list of itemsets (dataset).

    Parameters
    ----------
    dataset : list
        The dataset (a list of transactions) from which to generate candidate 
        itemsets.

    candidates : frozenset
        The list of candidate itemsets.

    min_support : float
        The minimum support threshold.

    Returns
    -------
    retlist : list
        The list of frequent itemsets.

    support_data : dict
        The support data for all candidate itemsets.
    """
    sscnt = {} # set for support counts
    for tid in dataset:
        for can in candidates:
            if can.issubset(tid):
                sscnt.setdefault(can, 0)
                sscnt[can] += 1

    num_items = float(len(dataset)) # total number of transactions in the dataset
    retlist = [] # array for unpruned itemsets
    support_data = {} # set for support data for corresponding itemsets
    for key in sscnt:
        # Calculate the support of itemset key.
        support = sscnt[key] / num_items
        if support >= min_support:
            retlist.insert(0, key)
        support_data[key] = support

    # Print a list of the pruned itemsets.
    if verbose:
        for kset in retlist:
            for item in kset:
                print("{" + str(item) + "}")
        print("")
        for key in sscnt:
            print("" \
                + "{" \
                + "".join([str(i) + ", " for i in iter(key)]).rstrip(', ') \
                + "}" \
                + ":  sup = " + str(support_data[key]))

    return retlist, support_data

def apriori_gen(freq_sets, k):
    """Generates candidate itemsets (via the F_k-1 x F_k-1 method).

    This operation generates new candidate k-itemsets based on the frequent 
    (k-1)-itemsets found in the previous iteration. The candidate generation 
    procedure merges a pair of frequent (k-1)-itemsets only if their first k-2 
    items are identical.

    Parameters
    ----------
    freq_sets : list
        The list of frequent (k-1)-itemsets.

    k : integer
        The cardinality of the current itemsets being evaluated.

    Returns
    -------
    retlist : list
        The list of merged frequent itemsets.
    """
    retList = [] # list of merged frequent itemsets
    lenLk = len(freq_sets) # number of frequent itemsets
    for i in range(lenLk):
        for j in range(i+1, lenLk):
            a=list(freq_sets[i])
            b=list(freq_sets[j])
            a.sort()
            b.sort()
            F1 = a[:k-2] # first k-2 items of freq_sets[i]
            F2 = b[:k-2] # first k-2 items of freq_sets[j]

            if F1 == F2: # if the first k-2 items are identical
                # Merge the frequent itemsets.
                retList.append(freq_sets[i] | freq_sets[j])

    return retList

def rules_from_conseq(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Generates a set of candidate rules.

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    support_data : dict
        The support data for all candidate itemsets.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.
    """
    m = len(H[0])
    if m == 1:
        Hmp1 = calc_confidence(freq_set, H, support_data, rules, min_confidence, verbose)
    if (len(freq_set) > (m+1)):
        Hmp1 = apriori_gen(H, m+1) # generate candidate itemsets
        Hmp1 = calc_confidence(freq_set, Hmp1, support_data, rules, min_confidence, verbose)
        if len(Hmp1) > 1:
            # If there are candidate rules above the minimum confidence 
            # threshold, recurse on the list of these candidate rules.
            rules_from_conseq(freq_set, Hmp1, support_data, rules, min_confidence, verbose)

def calc_confidence(freq_set, H, support_data, rules, min_confidence=0.5, verbose=False):
    """Evaluates the generated rules.

    One measurement for quantifying the goodness of association rules is 
    confidence. The confidence for a rule 'P implies H' (P -> H) is defined as 
    the support for P and H divided by the support for P 
    (support (P|H) / support(P)), where the | symbol denotes the set union 
    (thus P|H means all the items in set P or in set H).

    To calculate the confidence, we iterate through the frequent itemsets and 
    associated support data. For each frequent itemset, we divide the support 
    of the itemset by the support of the antecedent (left-hand-side of the 
    rule).

    Parameters
    ----------
    freq_set : frozenset
        The complete list of frequent itemsets.

    H : list
        A list of frequent itemsets (of a particular length).

    min_support : float
        The minimum support threshold.

    rules : list
        A potentially incomplete set of candidate rules above the minimum 
        confidence threshold.

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    pruned_H : list
        The list of candidate rules above the minimum confidence threshold.
    """
    pruned_H = [] # list of candidate rules above the minimum confidence threshold
    for conseq in H: # iterate over the frequent itemsets
        conf = support_data[freq_set] / support_data[freq_set - conseq]
        if conf >= min_confidence:
            rules.append((freq_set - conseq, conseq, conf))
            pruned_H.append(conseq)

            if verbose:
                print("" \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(freq_set-conseq)]).rstrip(', ') \
                    + "}" \
                    + " ---> " \
                    + "{" \
                    + "".join([str(i) + ", " for i in iter(conseq)]).rstrip(', ') \
                    + "}" \
                    + ":  conf = " + str(round(conf, 3)) \
                    + ", sup = " + str(round(support_data[freq_set], 3)))

    return pruned_H

def generate_rules(F, support_data, min_confidence=0.5, verbose=True):
    """Generates a set of candidate rules from a list of frequent itemsets.

    For each frequent itemset, we calculate the confidence of using a
    particular item as the rule consequent (right-hand-side of the rule). By 
    testing and merging the remaining rules, we recursively create a list of 
    pruned rules.

    Parameters
    ----------
    F : list
        A list of frequent itemsets.

    support_data : dict
        The corresponding support data for the frequent itemsets (L).

    min_confidence : float
        The minimum confidence threshold. Defaults to 0.5.

    Returns
    -------
    rules : list
        The list of candidate rules above the minimum confidence threshold.
    """
    rules = []
    for i in range(1, len(F)):
        for freq_set in F[i]:
            H1 = [frozenset([itemset]) for itemset in freq_set]
            if (i > 1):
                rules_from_conseq(freq_set, H1, support_data, rules, min_confidence, verbose)
            else:
                calc_confidence(freq_set, H1, support_data, rules, min_confidence, verbose)

    return rules

# %% [markdown]
# ### Load features data

# %%
# laod features dataset
dataset = load_dataset('features.csv')
# Change all features to a set format
D = list(map(set, dataset))

# %%
dataset.shape
# Out:
# (85796, 10)

# %%
D[0]
# Out:
# {'Above-Average',
#  'Adult',
#  'Budget',
#  'False',
#  'Large',
#  'Male',
#  'Public Assist',
#  'Spinone Italiano',
#  'Sporting',
#  'Yellow'}

# %%
# Generate all the frequent itemsets using the Apriori algorithm.
F, support_data = apriori(dataset, min_support=0.1, verbose=True)
# Out:
# {Baby}:  sup = 0.213
# {Young}:  sup = 0.287
# {Chihuahua}:  sup = 0.119
# {High-End}:  sup = 0.136
# {American Staffordshire Terrier}:  sup = 0.157
# {Terrier}:  sup = 0.23
# {Toy}:  sup = 0.179
# {Working}:  sup = 0.103
# {Tan}:  sup = 0.119
# {True}:  sup = 0.492
# {Owner Surrender}:  sup = 0.221
# {Average}:  sup = 0.22
# {White}:  sup = 0.18
# {Fair}:  sup = 0.168
# {Medium}:  sup = 0.518
# {Labrador Retriever}:  sup = 0.141
# {Female}:  sup = 0.464
# {Black}:  sup = 0.26
# {Small}:  sup = 0.289
# {Saver}:  sup = 0.483
# {Herding}:  sup = 0.164
# {Brown}:  sup = 0.136
# {Brightest}:  sup = 0.318
# {Stray}:  sup = 0.681
# {Senior}:  sup = 0.112
# {Sporting}:  sup = 0.171
# {Male}:  sup = 0.536
# {Large}:  sup = 0.193
# {False}:  sup = 0.508
# {Budget}:  sup = 0.312
# {Adult}:  sup = 0.388
# {Above-Average}:  sup = 0.199
# {Baby, Stray}:  sup = 0.156
# {Baby, Male}:  sup = 0.102
# {Baby, True}:  sup = 0.135
# {Baby, Female}:  sup = 0.111
# {Baby, Medium}:  sup = 0.113
# {Young, Male}:  sup = 0.155
# {Young, True}:  sup = 0.161
# {Young, Stray}:  sup = 0.203
# {Young, False}:  sup = 0.126
# {Young, Saver}:  sup = 0.141
# {Young, Female}:  sup = 0.133
# {Young, Medium}:  sup = 0.151
# {Adult, True}:  sup = 0.164
# {Adult, Female}:  sup = 0.169
# {Saver, Adult}:  sup = 0.197
# {Small, Adult}:  sup = 0.113
# {Terrier, Adult}:  sup = 0.108
# {Adult, Stray}:  sup = 0.253
# {Adult, Brightest}:  sup = 0.105
# {Adult, Medium}:  sup = 0.205
# {Terrier, True}:  sup = 0.105
# {Small, Female}:  sup = 0.131
# {White, Stray}:  sup = 0.124
# {Owner Surrender, Female}:  sup = 0.107
# {Toy, Stray}:  sup = 0.123
# {Small, Toy}:  sup = 0.174
# {Small, High-End}:  sup = 0.122
# {Fair, High-End}:  sup = 0.121
# {Toy, High-End}:  sup = 0.119
# {Small, Chihuahua}:  sup = 0.119
# {Fair, Chihuahua}:  sup = 0.119
# {Toy, Chihuahua}:  sup = 0.119
# {High-End, Chihuahua}:  sup = 0.119
# {Large, True}:  sup = 0.104
# {Female, True}:  sup = 0.239
# {Above-Average, Medium}:  sup = 0.161
# {Terrier, Above-Average}:  sup = 0.176
# {Terrier, Saver}:  sup = 0.183
# {American Staffordshire Terrier, Above-Average}:  sup = 0.157
# {American Staffordshire Terrier, Stray}:  sup = 0.103
# {Saver, American Staffordshire Terrier}:  sup = 0.157
# {American Staffordshire Terrier, Medium}:  sup = 0.157
# {Terrier, American Staffordshire Terrier}:  sup = 0.157
# {Terrier, Male}:  sup = 0.124
# {Budget, True}:  sup = 0.155
# {Stray, True}:  sup = 0.335
# {Brightest, True}:  sup = 0.172
# {Medium, True}:  sup = 0.257
# {False, Average}:  sup = 0.104
# {Stray, Average}:  sup = 0.15
# {Female, Average}:  sup = 0.102
# {Terrier, False}:  sup = 0.125
# {Terrier, Stray}:  sup = 0.154
# {Terrier, Female}:  sup = 0.106
# {Terrier, Medium}:  sup = 0.18
# {False, Toy}:  sup = 0.101
# {Toy, Fair}:  sup = 0.133
# {Saver, Above-Average}:  sup = 0.166
# {Stray, Herding}:  sup = 0.11
# {Saver, Large}:  sup = 0.143
# {Saver, Stray}:  sup = 0.326
# {Saver, Female}:  sup = 0.226
# {Male, Medium}:  sup = 0.274
# {Saver, Medium}:  sup = 0.248
# {Owner Surrender, Medium}:  sup = 0.113
# {Male, Black}:  sup = 0.139
# {Saver, Black}:  sup = 0.121
# {Male, Average}:  sup = 0.118
# {Male, Owner Surrender}:  sup = 0.114
# {Saver, Owner Surrender}:  sup = 0.106
# {Male, True}:  sup = 0.254
# {Saver, True}:  sup = 0.237
# {Small, True}:  sup = 0.131
# {Black, True}:  sup = 0.134
# {Average, True}:  sup = 0.116
# {Owner Surrender, True}:  sup = 0.14
# {Small, Stray}:  sup = 0.2
# {Fair, Stray}:  sup = 0.116
# {Small, Fair}:  sup = 0.135
# {Budget, Brightest}:  sup = 0.166
# {Sporting, Brightest}:  sup = 0.147
# {Brightest, Stray}:  sup = 0.219
# {False, Black}:  sup = 0.126
# {Stray, Black}:  sup = 0.177
# {Brightest, Black}:  sup = 0.129
# {Budget, Female}:  sup = 0.145
# {False, Female}:  sup = 0.225
# {Stray, Female}:  sup = 0.316
# {Brightest, Female}:  sup = 0.152
# {Black, Female}:  sup = 0.121
# {Budget, Labrador Retriever}:  sup = 0.141
# {Sporting, Labrador Retriever}:  sup = 0.141
# {Brightest, Labrador Retriever}:  sup = 0.141
# {Budget, Medium}:  sup = 0.231
# {False, Medium}:  sup = 0.262
# {Sporting, Medium}:  sup = 0.152
# {Stray, Medium}:  sup = 0.35
# {Brightest, Medium}:  sup = 0.227
# {Black, Medium}:  sup = 0.138
# {Female, Medium}:  sup = 0.245
# {Labrador Retriever, Medium}:  sup = 0.141
# {False, Brightest}:  sup = 0.146
# {Brightest, Male}:  sup = 0.166
# {Brightest, Herding}:  sup = 0.137
# {False, Saver}:  sup = 0.246
# {Saver, Male}:  sup = 0.258
# {Saver, Brightest}:  sup = 0.152
# {Saver, Herding}:  sup = 0.143
# {False, Small}:  sup = 0.158
# {Small, Male}:  sup = 0.157
# {Above-Average, Stray}:  sup = 0.132
# {Budget, Stray}:  sup = 0.218
# {False, Stray}:  sup = 0.346
# {Large, Stray}:  sup = 0.131
# {Male, Stray}:  sup = 0.365
# {Sporting, Stray}:  sup = 0.118
# {Budget, Adult}:  sup = 0.108
# {False, Above-Average}:  sup = 0.11
# {False, Adult}:  sup = 0.223
# {False, Budget}:  sup = 0.157
# {Above-Average, Male}:  sup = 0.108
# {Adult, Male}:  sup = 0.219
# {Budget, Male}:  sup = 0.167
# {False, Male}:  sup = 0.283
# {Large, Male}:  sup = 0.105
# {Budget, Sporting}:  sup = 0.153
# {Baby, Stray, True}:  sup = 0.1
# {Young, Stray, True}:  sup = 0.114
# {Young, Stray, Male}:  sup = 0.11
# {Young, Stray, Medium}:  sup = 0.105
# {Adult, Stray, True}:  sup = 0.106
# {Adult, Stray, Female}:  sup = 0.11
# {Saver, Adult, Medium}:  sup = 0.111
# {Saver, Adult, Male}:  sup = 0.11
# {False, Saver, Adult}:  sup = 0.113
# {Saver, Adult, Stray}:  sup = 0.127
# {Adult, Male, Medium}:  sup = 0.114
# {False, Adult, Medium}:  sup = 0.119
# {Male, Adult, Stray}:  sup = 0.143
# {False, Adult, Stray}:  sup = 0.147
# {Adult, Stray, Medium}:  sup = 0.131
# {Saver, Stray, True}:  sup = 0.159
# {Medium, Female, True}:  sup = 0.128
# {Saver, Medium, True}:  sup = 0.117
# {Saver, Female, True}:  sup = 0.117
# {Small, Toy, Fair}:  sup = 0.127
# {Toy, High-End, Chihuahua}:  sup = 0.119
# {Fair, High-End, Chihuahua}:  sup = 0.119
# {Fair, Chihuahua, Toy}:  sup = 0.119
# {Small, High-End, Chihuahua}:  sup = 0.119
# {Small, Toy, Chihuahua}:  sup = 0.119
# {Small, Fair, Chihuahua}:  sup = 0.119
# {Small, Fair, High-End}:  sup = 0.121
# {Fair, High-End, Toy}:  sup = 0.119
# {Small, Toy, High-End}:  sup = 0.119
# {Small, Toy, Stray}:  sup = 0.119
# {Stray, Female, True}:  sup = 0.161
# {Saver, Stray, Medium}:  sup = 0.164
# {Terrier, Saver, Medium}:  sup = 0.169
# {Terrier, False, Saver}:  sup = 0.103
# {Terrier, American Staffordshire Terrier, Medium}:  sup = 0.157
# {Terrier, Saver, American Staffordshire Terrier}:  sup = 0.157
# {Saver, American Staffordshire Terrier, Medium}:  sup = 0.157
# {Terrier, American Staffordshire Terrier, Stray}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Medium}:  sup = 0.103
# {Saver, American Staffordshire Terrier, Stray}:  sup = 0.103
# {Stray, American Staffordshire Terrier, Above-Average}:  sup = 0.103
# {Saver, American Staffordshire Terrier, Above-Average}:  sup = 0.157
# {Terrier, Saver, Stray}:  sup = 0.121
# {Terrier, Above-Average, Stray}:  sup = 0.116
# {Terrier, Saver, Above-Average}:  sup = 0.158
# {Terrier, American Staffordshire Terrier, Above-Average}:  sup = 0.157
# {Above-Average, Stray, Medium}:  sup = 0.105
# {Saver, Above-Average, Medium}:  sup = 0.16
# {American Staffordshire Terrier, Above-Average, Medium}:  sup = 0.157
# {Terrier, Above-Average, Medium}:  sup = 0.158
# {Saver, Medium, Female}:  sup = 0.119
# {Budget, Male, Medium}:  sup = 0.121
# {Male, Brightest, Stray}:  sup = 0.113
# {Stray, Male, True}:  sup = 0.174
# {Stray, Male, Medium}:  sup = 0.184
# {Male, Medium, True}:  sup = 0.128
# {Stray, Medium, True}:  sup = 0.173
# {Brightest, Medium, True}:  sup = 0.123
# {Brightest, Stray, True}:  sup = 0.117
# {Budget, Stray, True}:  sup = 0.107
# {Budget, Medium, True}:  sup = 0.121
# {Terrier, Stray, Medium}:  sup = 0.117
# {Saver, Stray, Male}:  sup = 0.173
# {Saver, Above-Average, Stray}:  sup = 0.108
# {False, Saver, Stray}:  sup = 0.167
# {False, Saver, Female}:  sup = 0.109
# {Saver, Brightest, Stray}:  sup = 0.103
# {Saver, Stray, Female}:  sup = 0.153
# {Brightest, Male, Medium}:  sup = 0.117
# {False, Male, Medium}:  sup = 0.145
# {False, Saver, Medium}:  sup = 0.131
# {Saver, Male, Medium}:  sup = 0.13
# {Saver, Male, True}:  sup = 0.12
# {Stray, Small, Male}:  sup = 0.111
# {False, Small, Stray}:  sup = 0.108
# {False, Brightest, Medium}:  sup = 0.104
# {Sporting, Stray, Medium}:  sup = 0.105
# {False, Stray, Medium}:  sup = 0.177
# {Budget, Sporting, Medium}:  sup = 0.148
# {False, Budget, Medium}:  sup = 0.109
# {Budget, Stray, Medium}:  sup = 0.161
# {Medium, Brightest, Labrador Retriever}:  sup = 0.141
# {Medium, Sporting, Labrador Retriever}:  sup = 0.141
# {Budget, Sporting, Labrador Retriever}:  sup = 0.141
# {Budget, Medium, Labrador Retriever}:  sup = 0.141
# {Medium, Brightest, Female}:  sup = 0.11
# {Medium, Stray, Female}:  sup = 0.167
# {False, Stray, Female}:  sup = 0.155
# {False, Medium, Female}:  sup = 0.117
# {Budget, Stray, Female}:  sup = 0.101
# {Budget, Medium, Female}:  sup = 0.11
# {False, Brightest, Stray}:  sup = 0.102
# {Brightest, Stray, Medium}:  sup = 0.157
# {Brightest, Stray, Female}:  sup = 0.106
# {Sporting, Brightest, Medium}:  sup = 0.147
# {Sporting, Brightest, Labrador Retriever}:  sup = 0.141
# {Sporting, Brightest, Stray}:  sup = 0.102
# {Budget, Brightest, Medium}:  sup = 0.165
# {Budget, Brightest, Labrador Retriever}:  sup = 0.141
# {Budget, Brightest, Stray}:  sup = 0.116
# {Budget, Sporting, Brightest}:  sup = 0.147
# {False, Saver, Male}:  sup = 0.137
# {Saver, Brightest, Herding}:  sup = 0.137
# {False, Male, Stray}:  sup = 0.191
# {Budget, Sporting, Stray}:  sup = 0.106
# {Budget, Male, Stray}:  sup = 0.116
# {False, Budget, Stray}:  sup = 0.111
# {False, Adult, Male}:  sup = 0.129
# {Small, Toy, Fair, High-End}:  sup = 0.119
# {Small, Toy, Fair, Chihuahua}:  sup = 0.119
# {Small, Fair, High-End, Chihuahua}:  sup = 0.119
# {Toy, Fair, High-End, Chihuahua}:  sup = 0.119
# {Small, Toy, High-End, Chihuahua}:  sup = 0.119
# {Above-Average, Terrier, Saver, Medium}:  sup = 0.158
# {Above-Average, Stray, Terrier, Medium}:  sup = 0.103
# {Above-Average, Stray, Saver, Medium}:  sup = 0.104
# {American Staffordshire Terrier, Above-Average, Terrier, Medium}:  sup = 0.157
# {Above-Average, Stray, Terrier, Saver}:  sup = 0.103
# {American Staffordshire Terrier, Above-Average, Saver, Medium}:  sup = 0.157
# {American Staffordshire Terrier, Above-Average, Terrier, Saver}:  sup = 0.157
# {American Staffordshire Terrier, Stray, Above-Average, Medium}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Above-Average, Terrier}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Above-Average, Saver}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Saver, Medium}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Saver}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Medium}:  sup = 0.103
# {American Staffordshire Terrier, Terrier, Saver, Medium}:  sup = 0.157
# {Stray, Terrier, Saver, Medium}:  sup = 0.11
# {Budget, Stray, Sporting, Brightest}:  sup = 0.102
# {Budget, Labrador Retriever, Sporting, Brightest}:  sup = 0.141
# {Budget, Sporting, Brightest, Medium}:  sup = 0.147
# {Budget, Stray, Brightest, Medium}:  sup = 0.115
# {Budget, Labrador Retriever, Brightest, Medium}:  sup = 0.141
# {Stray, Sporting, Brightest, Medium}:  sup = 0.102
# {Budget, Labrador Retriever, Sporting, Medium}:  sup = 0.141
# {Labrador Retriever, Sporting, Brightest, Medium}:  sup = 0.141
# {Budget, Stray, Sporting, Medium}:  sup = 0.102
# {Small, Fair, Toy, High-End, Chihuahua}:  sup = 0.119
# {American Staffordshire Terrier, Stray, Terrier, Saver, Medium}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Saver, Above-Average}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Saver, Medium, Above-Average}:  sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Medium, Above-Average}:  sup = 0.103
# {American Staffordshire Terrier, Terrier, Saver, Medium, Above-Average}:  sup = 0.157
# {Stray, Terrier, Saver, Medium, Above-Average}:  sup = 0.103
# {Budget, Stray, Brightest, Medium, Sporting}:  sup = 0.102
# {Budget, Labrador Retriever, Brightest, Medium, Sporting}:  sup = 0.141
# {American Staffordshire Terrier, Stray, Terrier, Saver, Medium, Above-Average}:  sup = 0.103

# %%
# Generate the association rules from a list of frequent itemsets.
H = generate_rules(F, support_data, min_confidence=0.2, verbose=True)
# Out:
# {Stray} ---> {Baby}:  conf = 0.229, sup = 0.156
# {Baby} ---> {Stray}:  conf = 0.732, sup = 0.156
# {Baby} ---> {Male}:  conf = 0.479, sup = 0.102
# {True} ---> {Baby}:  conf = 0.274, sup = 0.135
# {Baby} ---> {True}:  conf = 0.632, sup = 0.135
# {Female} ---> {Baby}:  conf = 0.24, sup = 0.111
# {Baby} ---> {Female}:  conf = 0.521, sup = 0.111
# {Medium} ---> {Baby}:  conf = 0.218, sup = 0.113
# {Baby} ---> {Medium}:  conf = 0.53, sup = 0.113
# {Male} ---> {Young}:  conf = 0.289, sup = 0.155
# {Young} ---> {Male}:  conf = 0.539, sup = 0.155
# {True} ---> {Young}:  conf = 0.327, sup = 0.161
# {Young} ---> {True}:  conf = 0.56, sup = 0.161
# {Stray} ---> {Young}:  conf = 0.299, sup = 0.203
# {Young} ---> {Stray}:  conf = 0.708, sup = 0.203
# {False} ---> {Young}:  conf = 0.249, sup = 0.126
# {Young} ---> {False}:  conf = 0.44, sup = 0.126
# {Saver} ---> {Young}:  conf = 0.293, sup = 0.141
# {Young} ---> {Saver}:  conf = 0.492, sup = 0.141
# {Female} ---> {Young}:  conf = 0.286, sup = 0.133
# {Young} ---> {Female}:  conf = 0.461, sup = 0.133
# {Medium} ---> {Young}:  conf = 0.29, sup = 0.151
# {Young} ---> {Medium}:  conf = 0.524, sup = 0.151
# {True} ---> {Adult}:  conf = 0.334, sup = 0.164
# {Adult} ---> {True}:  conf = 0.424, sup = 0.164
# {Female} ---> {Adult}:  conf = 0.364, sup = 0.169
# {Adult} ---> {Female}:  conf = 0.436, sup = 0.169
# {Adult} ---> {Saver}:  conf = 0.507, sup = 0.197
# {Saver} ---> {Adult}:  conf = 0.407, sup = 0.197
# {Adult} ---> {Small}:  conf = 0.292, sup = 0.113
# {Small} ---> {Adult}:  conf = 0.392, sup = 0.113
# {Adult} ---> {Terrier}:  conf = 0.277, sup = 0.108
# {Terrier} ---> {Adult}:  conf = 0.468, sup = 0.108
# {Stray} ---> {Adult}:  conf = 0.371, sup = 0.253
# {Adult} ---> {Stray}:  conf = 0.652, sup = 0.253
# {Brightest} ---> {Adult}:  conf = 0.329, sup = 0.105
# {Adult} ---> {Brightest}:  conf = 0.27, sup = 0.105
# {Medium} ---> {Adult}:  conf = 0.396, sup = 0.205
# {Adult} ---> {Medium}:  conf = 0.529, sup = 0.205
# {True} ---> {Terrier}:  conf = 0.213, sup = 0.105
# {Terrier} ---> {True}:  conf = 0.455, sup = 0.105
# {Female} ---> {Small}:  conf = 0.283, sup = 0.131
# {Small} ---> {Female}:  conf = 0.455, sup = 0.131
# {White} ---> {Stray}:  conf = 0.69, sup = 0.124
# {Female} ---> {Owner Surrender}:  conf = 0.231, sup = 0.107
# {Owner Surrender} ---> {Female}:  conf = 0.485, sup = 0.107
# {Toy} ---> {Stray}:  conf = 0.688, sup = 0.123
# {Toy} ---> {Small}:  conf = 0.97, sup = 0.174
# {Small} ---> {Toy}:  conf = 0.603, sup = 0.174
# {High-End} ---> {Small}:  conf = 0.897, sup = 0.122
# {Small} ---> {High-End}:  conf = 0.422, sup = 0.122
# {High-End} ---> {Fair}:  conf = 0.892, sup = 0.121
# {Fair} ---> {High-End}:  conf = 0.722, sup = 0.121
# {High-End} ---> {Toy}:  conf = 0.877, sup = 0.119
# {Toy} ---> {High-End}:  conf = 0.664, sup = 0.119
# {Chihuahua} ---> {Small}:  conf = 1.0, sup = 0.119
# {Small} ---> {Chihuahua}:  conf = 0.412, sup = 0.119
# {Chihuahua} ---> {Fair}:  conf = 1.0, sup = 0.119
# {Fair} ---> {Chihuahua}:  conf = 0.709, sup = 0.119
# {Chihuahua} ---> {Toy}:  conf = 1.0, sup = 0.119
# {Toy} ---> {Chihuahua}:  conf = 0.664, sup = 0.119
# {Chihuahua} ---> {High-End}:  conf = 1.0, sup = 0.119
# {High-End} ---> {Chihuahua}:  conf = 0.877, sup = 0.119
# {True} ---> {Large}:  conf = 0.212, sup = 0.104
# {Large} ---> {True}:  conf = 0.542, sup = 0.104
# {True} ---> {Female}:  conf = 0.485, sup = 0.239
# {Female} ---> {True}:  conf = 0.515, sup = 0.239
# {Medium} ---> {Above-Average}:  conf = 0.311, sup = 0.161
# {Above-Average} ---> {Medium}:  conf = 0.812, sup = 0.161
# {Above-Average} ---> {Terrier}:  conf = 0.885, sup = 0.176
# {Terrier} ---> {Above-Average}:  conf = 0.765, sup = 0.176
# {Saver} ---> {Terrier}:  conf = 0.379, sup = 0.183
# {Terrier} ---> {Saver}:  conf = 0.796, sup = 0.183
# {Above-Average} ---> {American Staffordshire Terrier}:  conf = 0.792, sup = 0.157
# {American Staffordshire Terrier} ---> {Above-Average}:  conf = 1.0, sup = 0.157
# {American Staffordshire Terrier} ---> {Stray}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier} ---> {Saver}:  conf = 1.0, sup = 0.157
# {Saver} ---> {American Staffordshire Terrier}:  conf = 0.326, sup = 0.157
# {Medium} ---> {American Staffordshire Terrier}:  conf = 0.304, sup = 0.157
# {American Staffordshire Terrier} ---> {Medium}:  conf = 1.0, sup = 0.157
# {American Staffordshire Terrier} ---> {Terrier}:  conf = 1.0, sup = 0.157
# {Terrier} ---> {American Staffordshire Terrier}:  conf = 0.685, sup = 0.157
# {Male} ---> {Terrier}:  conf = 0.231, sup = 0.124
# {Terrier} ---> {Male}:  conf = 0.539, sup = 0.124
# {True} ---> {Budget}:  conf = 0.315, sup = 0.155
# {Budget} ---> {True}:  conf = 0.497, sup = 0.155
# {True} ---> {Stray}:  conf = 0.681, sup = 0.335
# {Stray} ---> {True}:  conf = 0.492, sup = 0.335
# {True} ---> {Brightest}:  conf = 0.35, sup = 0.172
# {Brightest} ---> {True}:  conf = 0.54, sup = 0.172
# {True} ---> {Medium}:  conf = 0.522, sup = 0.257
# {Medium} ---> {True}:  conf = 0.495, sup = 0.257
# {Average} ---> {False}:  conf = 0.473, sup = 0.104
# {False} ---> {Average}:  conf = 0.205, sup = 0.104
# {Average} ---> {Stray}:  conf = 0.682, sup = 0.15
# {Stray} ---> {Average}:  conf = 0.22, sup = 0.15
# {Average} ---> {Female}:  conf = 0.465, sup = 0.102
# {Female} ---> {Average}:  conf = 0.221, sup = 0.102
# {False} ---> {Terrier}:  conf = 0.247, sup = 0.125
# {Terrier} ---> {False}:  conf = 0.545, sup = 0.125
# {Stray} ---> {Terrier}:  conf = 0.226, sup = 0.154
# {Terrier} ---> {Stray}:  conf = 0.668, sup = 0.154
# {Female} ---> {Terrier}:  conf = 0.229, sup = 0.106
# {Terrier} ---> {Female}:  conf = 0.461, sup = 0.106
# {Medium} ---> {Terrier}:  conf = 0.347, sup = 0.18
# {Terrier} ---> {Medium}:  conf = 0.783, sup = 0.18
# {Toy} ---> {False}:  conf = 0.565, sup = 0.101
# {Fair} ---> {Toy}:  conf = 0.791, sup = 0.133
# {Toy} ---> {Fair}:  conf = 0.74, sup = 0.133
# {Above-Average} ---> {Saver}:  conf = 0.835, sup = 0.166
# {Saver} ---> {Above-Average}:  conf = 0.344, sup = 0.166
# {Herding} ---> {Stray}:  conf = 0.674, sup = 0.11
# {Large} ---> {Saver}:  conf = 0.744, sup = 0.143
# {Saver} ---> {Large}:  conf = 0.297, sup = 0.143
# {Stray} ---> {Saver}:  conf = 0.478, sup = 0.326
# {Saver} ---> {Stray}:  conf = 0.674, sup = 0.326
# {Female} ---> {Saver}:  conf = 0.486, sup = 0.226
# {Saver} ---> {Female}:  conf = 0.467, sup = 0.226
# {Medium} ---> {Male}:  conf = 0.528, sup = 0.274
# {Male} ---> {Medium}:  conf = 0.51, sup = 0.274
# {Medium} ---> {Saver}:  conf = 0.479, sup = 0.248
# {Saver} ---> {Medium}:  conf = 0.514, sup = 0.248
# {Medium} ---> {Owner Surrender}:  conf = 0.219, sup = 0.113
# {Owner Surrender} ---> {Medium}:  conf = 0.512, sup = 0.113
# {Black} ---> {Male}:  conf = 0.534, sup = 0.139
# {Male} ---> {Black}:  conf = 0.259, sup = 0.139
# {Black} ---> {Saver}:  conf = 0.464, sup = 0.121
# {Saver} ---> {Black}:  conf = 0.25, sup = 0.121
# {Average} ---> {Male}:  conf = 0.535, sup = 0.118
# {Male} ---> {Average}:  conf = 0.22, sup = 0.118
# {Owner Surrender} ---> {Male}:  conf = 0.515, sup = 0.114
# {Male} ---> {Owner Surrender}:  conf = 0.213, sup = 0.114
# {Owner Surrender} ---> {Saver}:  conf = 0.477, sup = 0.106
# {Saver} ---> {Owner Surrender}:  conf = 0.218, sup = 0.106
# {True} ---> {Male}:  conf = 0.515, sup = 0.254
# {Male} ---> {True}:  conf = 0.473, sup = 0.254
# {True} ---> {Saver}:  conf = 0.481, sup = 0.237
# {Saver} ---> {True}:  conf = 0.49, sup = 0.237
# {True} ---> {Small}:  conf = 0.266, sup = 0.131
# {Small} ---> {True}:  conf = 0.454, sup = 0.131
# {True} ---> {Black}:  conf = 0.272, sup = 0.134
# {Black} ---> {True}:  conf = 0.514, sup = 0.134
# {True} ---> {Average}:  conf = 0.236, sup = 0.116
# {Average} ---> {True}:  conf = 0.527, sup = 0.116
# {True} ---> {Owner Surrender}:  conf = 0.283, sup = 0.14
# {Owner Surrender} ---> {True}:  conf = 0.63, sup = 0.14
# {Stray} ---> {Small}:  conf = 0.294, sup = 0.2
# {Small} ---> {Stray}:  conf = 0.693, sup = 0.2
# {Fair} ---> {Stray}:  conf = 0.691, sup = 0.116
# {Fair} ---> {Small}:  conf = 0.802, sup = 0.135
# {Small} ---> {Fair}:  conf = 0.466, sup = 0.135
# {Brightest} ---> {Budget}:  conf = 0.522, sup = 0.166
# {Budget} ---> {Brightest}:  conf = 0.533, sup = 0.166
# {Brightest} ---> {Sporting}:  conf = 0.46, sup = 0.147
# {Sporting} ---> {Brightest}:  conf = 0.855, sup = 0.147
# {Stray} ---> {Brightest}:  conf = 0.322, sup = 0.219
# {Brightest} ---> {Stray}:  conf = 0.688, sup = 0.219
# {Black} ---> {False}:  conf = 0.486, sup = 0.126
# {False} ---> {Black}:  conf = 0.249, sup = 0.126
# {Black} ---> {Stray}:  conf = 0.679, sup = 0.177
# {Stray} ---> {Black}:  conf = 0.259, sup = 0.177
# {Black} ---> {Brightest}:  conf = 0.496, sup = 0.129
# {Brightest} ---> {Black}:  conf = 0.406, sup = 0.129
# {Female} ---> {Budget}:  conf = 0.313, sup = 0.145
# {Budget} ---> {Female}:  conf = 0.465, sup = 0.145
# {Female} ---> {False}:  conf = 0.485, sup = 0.225
# {False} ---> {Female}:  conf = 0.443, sup = 0.225
# {Female} ---> {Stray}:  conf = 0.682, sup = 0.316
# {Stray} ---> {Female}:  conf = 0.464, sup = 0.316
# {Female} ---> {Brightest}:  conf = 0.328, sup = 0.152
# {Brightest} ---> {Female}:  conf = 0.478, sup = 0.152
# {Female} ---> {Black}:  conf = 0.261, sup = 0.121
# {Black} ---> {Female}:  conf = 0.466, sup = 0.121
# {Labrador Retriever} ---> {Budget}:  conf = 1.0, sup = 0.141
# {Budget} ---> {Labrador Retriever}:  conf = 0.453, sup = 0.141
# {Labrador Retriever} ---> {Sporting}:  conf = 1.0, sup = 0.141
# {Sporting} ---> {Labrador Retriever}:  conf = 0.823, sup = 0.141
# {Labrador Retriever} ---> {Brightest}:  conf = 1.0, sup = 0.141
# {Brightest} ---> {Labrador Retriever}:  conf = 0.443, sup = 0.141
# {Medium} ---> {Budget}:  conf = 0.445, sup = 0.231
# {Budget} ---> {Medium}:  conf = 0.741, sup = 0.231
# {Medium} ---> {False}:  conf = 0.505, sup = 0.262
# {False} ---> {Medium}:  conf = 0.515, sup = 0.262
# {Medium} ---> {Sporting}:  conf = 0.293, sup = 0.152
# {Sporting} ---> {Medium}:  conf = 0.886, sup = 0.152
# {Medium} ---> {Stray}:  conf = 0.676, sup = 0.35
# {Stray} ---> {Medium}:  conf = 0.514, sup = 0.35
# {Medium} ---> {Brightest}:  conf = 0.438, sup = 0.227
# {Brightest} ---> {Medium}:  conf = 0.712, sup = 0.227
# {Medium} ---> {Black}:  conf = 0.266, sup = 0.138
# {Black} ---> {Medium}:  conf = 0.53, sup = 0.138
# {Medium} ---> {Female}:  conf = 0.472, sup = 0.245
# {Female} ---> {Medium}:  conf = 0.528, sup = 0.245
# {Medium} ---> {Labrador Retriever}:  conf = 0.272, sup = 0.141
# {Labrador Retriever} ---> {Medium}:  conf = 1.0, sup = 0.141
# {Brightest} ---> {False}:  conf = 0.46, sup = 0.146
# {False} ---> {Brightest}:  conf = 0.288, sup = 0.146
# {Male} ---> {Brightest}:  conf = 0.31, sup = 0.166
# {Brightest} ---> {Male}:  conf = 0.522, sup = 0.166
# {Herding} ---> {Brightest}:  conf = 0.835, sup = 0.137
# {Brightest} ---> {Herding}:  conf = 0.429, sup = 0.137
# {Saver} ---> {False}:  conf = 0.51, sup = 0.246
# {False} ---> {Saver}:  conf = 0.485, sup = 0.246
# {Male} ---> {Saver}:  conf = 0.48, sup = 0.258
# {Saver} ---> {Male}:  conf = 0.533, sup = 0.258
# {Brightest} ---> {Saver}:  conf = 0.478, sup = 0.152
# {Saver} ---> {Brightest}:  conf = 0.315, sup = 0.152
# {Herding} ---> {Saver}:  conf = 0.877, sup = 0.143
# {Saver} ---> {Herding}:  conf = 0.297, sup = 0.143
# {Small} ---> {False}:  conf = 0.546, sup = 0.158
# {False} ---> {Small}:  conf = 0.311, sup = 0.158
# {Male} ---> {Small}:  conf = 0.294, sup = 0.157
# {Small} ---> {Male}:  conf = 0.545, sup = 0.157
# {Above-Average} ---> {Stray}:  conf = 0.662, sup = 0.132
# {Stray} ---> {Budget}:  conf = 0.319, sup = 0.218
# {Budget} ---> {Stray}:  conf = 0.698, sup = 0.218
# {Stray} ---> {False}:  conf = 0.508, sup = 0.346
# {False} ---> {Stray}:  conf = 0.682, sup = 0.346
# {Large} ---> {Stray}:  conf = 0.679, sup = 0.131
# {Stray} ---> {Male}:  conf = 0.536, sup = 0.365
# {Male} ---> {Stray}:  conf = 0.681, sup = 0.365
# {Sporting} ---> {Stray}:  conf = 0.69, sup = 0.118
# {Adult} ---> {Budget}:  conf = 0.279, sup = 0.108
# {Budget} ---> {Adult}:  conf = 0.348, sup = 0.108
# {Above-Average} ---> {False}:  conf = 0.552, sup = 0.11
# {False} ---> {Above-Average}:  conf = 0.216, sup = 0.11
# {Adult} ---> {False}:  conf = 0.576, sup = 0.223
# {False} ---> {Adult}:  conf = 0.44, sup = 0.223
# {Budget} ---> {False}:  conf = 0.503, sup = 0.157
# {False} ---> {Budget}:  conf = 0.308, sup = 0.157
# {Male} ---> {Above-Average}:  conf = 0.201, sup = 0.108
# {Above-Average} ---> {Male}:  conf = 0.542, sup = 0.108
# {Male} ---> {Adult}:  conf = 0.408, sup = 0.219
# {Adult} ---> {Male}:  conf = 0.564, sup = 0.219
# {Male} ---> {Budget}:  conf = 0.311, sup = 0.167
# {Budget} ---> {Male}:  conf = 0.535, sup = 0.167
# {Male} ---> {False}:  conf = 0.527, sup = 0.283
# {False} ---> {Male}:  conf = 0.557, sup = 0.283
# {Large} ---> {Male}:  conf = 0.546, sup = 0.105
# {Sporting} ---> {Budget}:  conf = 0.894, sup = 0.153
# {Budget} ---> {Sporting}:  conf = 0.492, sup = 0.153
# {Stray, True} ---> {Baby}:  conf = 0.298, sup = 0.1
# {Baby, True} ---> {Stray}:  conf = 0.742, sup = 0.1
# {Baby, Stray} ---> {True}:  conf = 0.641, sup = 0.1
# {True} ---> {Baby, Stray}:  conf = 0.203, sup = 0.1
# {Baby} ---> {Stray, True}:  conf = 0.469, sup = 0.1
# {Stray, True} ---> {Young}:  conf = 0.339, sup = 0.114
# {Young, True} ---> {Stray}:  conf = 0.706, sup = 0.114
# {Young, Stray} ---> {True}:  conf = 0.559, sup = 0.114
# {True} ---> {Young, Stray}:  conf = 0.231, sup = 0.114
# {Young} ---> {Stray, True}:  conf = 0.396, sup = 0.114
# {Male, Stray} ---> {Young}:  conf = 0.302, sup = 0.11
# {Young, Male} ---> {Stray}:  conf = 0.711, sup = 0.11
# {Young, Stray} ---> {Male}:  conf = 0.541, sup = 0.11
# {Male} ---> {Young, Stray}:  conf = 0.205, sup = 0.11
# {Young} ---> {Male, Stray}:  conf = 0.383, sup = 0.11
# {Stray, Medium} ---> {Young}:  conf = 0.3, sup = 0.105
# {Young, Medium} ---> {Stray}:  conf = 0.698, sup = 0.105
# {Young, Stray} ---> {Medium}:  conf = 0.516, sup = 0.105
# {Medium} ---> {Young, Stray}:  conf = 0.203, sup = 0.105
# {Young} ---> {Stray, Medium}:  conf = 0.366, sup = 0.105
# {Stray, True} ---> {Adult}:  conf = 0.316, sup = 0.106
# {Adult, True} ---> {Stray}:  conf = 0.644, sup = 0.106
# {Adult, Stray} ---> {True}:  conf = 0.419, sup = 0.106
# {True} ---> {Adult, Stray}:  conf = 0.215, sup = 0.106
# {Adult} ---> {Stray, True}:  conf = 0.273, sup = 0.106
# {Stray, Female} ---> {Adult}:  conf = 0.348, sup = 0.11
# {Adult, Female} ---> {Stray}:  conf = 0.651, sup = 0.11
# {Adult, Stray} ---> {Female}:  conf = 0.435, sup = 0.11
# {Female} ---> {Adult, Stray}:  conf = 0.237, sup = 0.11
# {Adult} ---> {Stray, Female}:  conf = 0.284, sup = 0.11
# {Adult, Medium} ---> {Saver}:  conf = 0.539, sup = 0.111
# {Saver, Medium} ---> {Adult}:  conf = 0.445, sup = 0.111
# {Saver, Adult} ---> {Medium}:  conf = 0.562, sup = 0.111
# {Medium} ---> {Saver, Adult}:  conf = 0.213, sup = 0.111
# {Adult} ---> {Saver, Medium}:  conf = 0.285, sup = 0.111
# {Saver} ---> {Adult, Medium}:  conf = 0.229, sup = 0.111
# {Adult, Male} ---> {Saver}:  conf = 0.504, sup = 0.11
# {Saver, Male} ---> {Adult}:  conf = 0.428, sup = 0.11
# {Saver, Adult} ---> {Male}:  conf = 0.561, sup = 0.11
# {Male} ---> {Saver, Adult}:  conf = 0.206, sup = 0.11
# {Adult} ---> {Saver, Male}:  conf = 0.284, sup = 0.11
# {Saver} ---> {Adult, Male}:  conf = 0.228, sup = 0.11
# {Saver, Adult} ---> {False}:  conf = 0.576, sup = 0.113
# {False, Adult} ---> {Saver}:  conf = 0.507, sup = 0.113
# {False, Saver} ---> {Adult}:  conf = 0.46, sup = 0.113
# {Adult} ---> {False, Saver}:  conf = 0.292, sup = 0.113
# {Saver} ---> {False, Adult}:  conf = 0.234, sup = 0.113
# {False} ---> {Saver, Adult}:  conf = 0.223, sup = 0.113
# {Adult, Stray} ---> {Saver}:  conf = 0.502, sup = 0.127
# {Saver, Stray} ---> {Adult}:  conf = 0.39, sup = 0.127
# {Saver, Adult} ---> {Stray}:  conf = 0.646, sup = 0.127
# {Adult} ---> {Saver, Stray}:  conf = 0.327, sup = 0.127
# {Saver} ---> {Adult, Stray}:  conf = 0.263, sup = 0.127
# {Male, Medium} ---> {Adult}:  conf = 0.418, sup = 0.114
# {Adult, Medium} ---> {Male}:  conf = 0.557, sup = 0.114
# {Adult, Male} ---> {Medium}:  conf = 0.522, sup = 0.114
# {Medium} ---> {Adult, Male}:  conf = 0.22, sup = 0.114
# {Male} ---> {Adult, Medium}:  conf = 0.213, sup = 0.114
# {Adult} ---> {Male, Medium}:  conf = 0.295, sup = 0.114
# {Adult, Medium} ---> {False}:  conf = 0.58, sup = 0.119
# {False, Medium} ---> {Adult}:  conf = 0.455, sup = 0.119
# {False, Adult} ---> {Medium}:  conf = 0.533, sup = 0.119
# {Medium} ---> {False, Adult}:  conf = 0.23, sup = 0.119
# {Adult} ---> {False, Medium}:  conf = 0.307, sup = 0.119
# {False} ---> {Adult, Medium}:  conf = 0.235, sup = 0.119
# {Adult, Stray} ---> {Male}:  conf = 0.565, sup = 0.143
# {Stray, Male} ---> {Adult}:  conf = 0.391, sup = 0.143
# {Adult, Male} ---> {Stray}:  conf = 0.653, sup = 0.143
# {Stray} ---> {Adult, Male}:  conf = 0.21, sup = 0.143
# {Adult} ---> {Stray, Male}:  conf = 0.368, sup = 0.143
# {Male} ---> {Adult, Stray}:  conf = 0.266, sup = 0.143
# {Adult, Stray} ---> {False}:  conf = 0.581, sup = 0.147
# {False, Stray} ---> {Adult}:  conf = 0.425, sup = 0.147
# {False, Adult} ---> {Stray}:  conf = 0.658, sup = 0.147
# {Stray} ---> {False, Adult}:  conf = 0.216, sup = 0.147
# {Adult} ---> {False, Stray}:  conf = 0.379, sup = 0.147
# {False} ---> {Adult, Stray}:  conf = 0.29, sup = 0.147
# {Stray, Medium} ---> {Adult}:  conf = 0.374, sup = 0.131
# {Adult, Medium} ---> {Stray}:  conf = 0.64, sup = 0.131
# {Adult, Stray} ---> {Medium}:  conf = 0.519, sup = 0.131
# {Medium} ---> {Adult, Stray}:  conf = 0.253, sup = 0.131
# {Adult} ---> {Stray, Medium}:  conf = 0.338, sup = 0.131
# {Stray, True} ---> {Saver}:  conf = 0.475, sup = 0.159
# {Saver, True} ---> {Stray}:  conf = 0.673, sup = 0.159
# {Saver, Stray} ---> {True}:  conf = 0.489, sup = 0.159
# {True} ---> {Saver, Stray}:  conf = 0.324, sup = 0.159
# {Stray} ---> {Saver, True}:  conf = 0.234, sup = 0.159
# {Saver} ---> {Stray, True}:  conf = 0.33, sup = 0.159
# {Female, True} ---> {Medium}:  conf = 0.537, sup = 0.128
# {Medium, True} ---> {Female}:  conf = 0.5, sup = 0.128
# {Female, Medium} ---> {True}:  conf = 0.524, sup = 0.128
# {True} ---> {Female, Medium}:  conf = 0.261, sup = 0.128
# {Female} ---> {Medium, True}:  conf = 0.277, sup = 0.128
# {Medium} ---> {Female, True}:  conf = 0.247, sup = 0.128
# {Medium, True} ---> {Saver}:  conf = 0.456, sup = 0.117
# {Saver, True} ---> {Medium}:  conf = 0.495, sup = 0.117
# {Saver, Medium} ---> {True}:  conf = 0.472, sup = 0.117
# {True} ---> {Saver, Medium}:  conf = 0.238, sup = 0.117
# {Medium} ---> {Saver, True}:  conf = 0.226, sup = 0.117
# {Saver} ---> {Medium, True}:  conf = 0.242, sup = 0.117
# {Female, True} ---> {Saver}:  conf = 0.489, sup = 0.117
# {Saver, True} ---> {Female}:  conf = 0.493, sup = 0.117
# {Saver, Female} ---> {True}:  conf = 0.517, sup = 0.117
# {True} ---> {Saver, Female}:  conf = 0.237, sup = 0.117
# {Female} ---> {Saver, True}:  conf = 0.252, sup = 0.117
# {Saver} ---> {Female, True}:  conf = 0.241, sup = 0.117
# {Toy, Fair} ---> {Small}:  conf = 0.959, sup = 0.127
# {Small, Fair} ---> {Toy}:  conf = 0.946, sup = 0.127
# {Small, Toy} ---> {Fair}:  conf = 0.732, sup = 0.127
# {Fair} ---> {Small, Toy}:  conf = 0.759, sup = 0.127
# {Toy} ---> {Small, Fair}:  conf = 0.71, sup = 0.127
# {Small} ---> {Toy, Fair}:  conf = 0.441, sup = 0.127
# {High-End, Chihuahua} ---> {Toy}:  conf = 1.0, sup = 0.119
# {Toy, Chihuahua} ---> {High-End}:  conf = 1.0, sup = 0.119
# {Toy, High-End} ---> {Chihuahua}:  conf = 1.0, sup = 0.119
# {Chihuahua} ---> {Toy, High-End}:  conf = 1.0, sup = 0.119
# {High-End} ---> {Toy, Chihuahua}:  conf = 0.877, sup = 0.119
# {Toy} ---> {High-End, Chihuahua}:  conf = 0.664, sup = 0.119
# {High-End, Chihuahua} ---> {Fair}:  conf = 1.0, sup = 0.119
# {Fair, Chihuahua} ---> {High-End}:  conf = 1.0, sup = 0.119
# {Fair, High-End} ---> {Chihuahua}:  conf = 0.983, sup = 0.119
# {Chihuahua} ---> {Fair, High-End}:  conf = 1.0, sup = 0.119
# {High-End} ---> {Fair, Chihuahua}:  conf = 0.877, sup = 0.119
# {Fair} ---> {High-End, Chihuahua}:  conf = 0.709, sup = 0.119
# {Toy, Chihuahua} ---> {Fair}:  conf = 1.0, sup = 0.119
# {Fair, Toy} ---> {Chihuahua}:  conf = 0.897, sup = 0.119
# {Fair, Chihuahua} ---> {Toy}:  conf = 1.0, sup = 0.119
# {Toy} ---> {Fair, Chihuahua}:  conf = 0.664, sup = 0.119
# {Chihuahua} ---> {Fair, Toy}:  conf = 1.0, sup = 0.119
# {Fair} ---> {Toy, Chihuahua}:  conf = 0.709, sup = 0.119
# {High-End, Chihuahua} ---> {Small}:  conf = 1.0, sup = 0.119
# {Small, Chihuahua} ---> {High-End}:  conf = 1.0, sup = 0.119
# {Small, High-End} ---> {Chihuahua}:  conf = 0.978, sup = 0.119
# {Chihuahua} ---> {Small, High-End}:  conf = 1.0, sup = 0.119
# {High-End} ---> {Small, Chihuahua}:  conf = 0.877, sup = 0.119
# {Small} ---> {High-End, Chihuahua}:  conf = 0.412, sup = 0.119
# {Toy, Chihuahua} ---> {Small}:  conf = 1.0, sup = 0.119
# {Small, Chihuahua} ---> {Toy}:  conf = 1.0, sup = 0.119
# {Small, Toy} ---> {Chihuahua}:  conf = 0.684, sup = 0.119
# {Chihuahua} ---> {Small, Toy}:  conf = 1.0, sup = 0.119
# {Toy} ---> {Small, Chihuahua}:  conf = 0.664, sup = 0.119
# {Small} ---> {Toy, Chihuahua}:  conf = 0.412, sup = 0.119
# {Fair, Chihuahua} ---> {Small}:  conf = 1.0, sup = 0.119
# {Small, Chihuahua} ---> {Fair}:  conf = 1.0, sup = 0.119
# {Small, Fair} ---> {Chihuahua}:  conf = 0.885, sup = 0.119
# {Chihuahua} ---> {Small, Fair}:  conf = 1.0, sup = 0.119
# {Fair} ---> {Small, Chihuahua}:  conf = 0.709, sup = 0.119
# {Small} ---> {Fair, Chihuahua}:  conf = 0.412, sup = 0.119
# {Fair, High-End} ---> {Small}:  conf = 1.0, sup = 0.121
# {Small, High-End} ---> {Fair}:  conf = 0.995, sup = 0.121
# {Small, Fair} ---> {High-End}:  conf = 0.9, sup = 0.121
# {High-End} ---> {Small, Fair}:  conf = 0.892, sup = 0.121
# {Fair} ---> {Small, High-End}:  conf = 0.722, sup = 0.121
# {Small} ---> {Fair, High-End}:  conf = 0.42, sup = 0.121
# {Toy, High-End} ---> {Fair}:  conf = 1.0, sup = 0.119
# {Fair, Toy} ---> {High-End}:  conf = 0.897, sup = 0.119
# {Fair, High-End} ---> {Toy}:  conf = 0.983, sup = 0.119
# {Toy} ---> {Fair, High-End}:  conf = 0.664, sup = 0.119
# {High-End} ---> {Fair, Toy}:  conf = 0.877, sup = 0.119
# {Fair} ---> {Toy, High-End}:  conf = 0.709, sup = 0.119
# {Toy, High-End} ---> {Small}:  conf = 1.0, sup = 0.119
# {Small, High-End} ---> {Toy}:  conf = 0.978, sup = 0.119
# {Small, Toy} ---> {High-End}:  conf = 0.684, sup = 0.119
# {High-End} ---> {Small, Toy}:  conf = 0.877, sup = 0.119
# {Toy} ---> {Small, High-End}:  conf = 0.664, sup = 0.119
# {Small} ---> {Toy, High-End}:  conf = 0.412, sup = 0.119
# {Toy, Stray} ---> {Small}:  conf = 0.966, sup = 0.119
# {Small, Stray} ---> {Toy}:  conf = 0.596, sup = 0.119
# {Small, Toy} ---> {Stray}:  conf = 0.685, sup = 0.119
# {Toy} ---> {Small, Stray}:  conf = 0.664, sup = 0.119
# {Small} ---> {Toy, Stray}:  conf = 0.413, sup = 0.119
# {Female, True} ---> {Stray}:  conf = 0.676, sup = 0.161
# {Stray, True} ---> {Female}:  conf = 0.482, sup = 0.161
# {Stray, Female} ---> {True}:  conf = 0.511, sup = 0.161
# {True} ---> {Stray, Female}:  conf = 0.328, sup = 0.161
# {Female} ---> {Stray, True}:  conf = 0.348, sup = 0.161
# {Stray} ---> {Female, True}:  conf = 0.237, sup = 0.161
# {Stray, Medium} ---> {Saver}:  conf = 0.468, sup = 0.164
# {Saver, Medium} ---> {Stray}:  conf = 0.66, sup = 0.164
# {Saver, Stray} ---> {Medium}:  conf = 0.503, sup = 0.164
# {Medium} ---> {Saver, Stray}:  conf = 0.316, sup = 0.164
# {Stray} ---> {Saver, Medium}:  conf = 0.241, sup = 0.164
# {Saver} ---> {Stray, Medium}:  conf = 0.339, sup = 0.164
# {Saver, Medium} ---> {Terrier}:  conf = 0.681, sup = 0.169
# {Terrier, Medium} ---> {Saver}:  conf = 0.939, sup = 0.169
# {Terrier, Saver} ---> {Medium}:  conf = 0.923, sup = 0.169
# {Medium} ---> {Terrier, Saver}:  conf = 0.326, sup = 0.169
# {Saver} ---> {Terrier, Medium}:  conf = 0.35, sup = 0.169
# {Terrier} ---> {Saver, Medium}:  conf = 0.735, sup = 0.169
# {False, Saver} ---> {Terrier}:  conf = 0.419, sup = 0.103
# {Terrier, Saver} ---> {False}:  conf = 0.565, sup = 0.103
# {Terrier, False} ---> {Saver}:  conf = 0.825, sup = 0.103
# {Saver} ---> {Terrier, False}:  conf = 0.214, sup = 0.103
# {False} ---> {Terrier, Saver}:  conf = 0.204, sup = 0.103
# {Terrier} ---> {False, Saver}:  conf = 0.449, sup = 0.103
# {American Staffordshire Terrier, Medium} ---> {Terrier}:  conf = 1.0, sup = 0.157
# {Terrier, Medium} ---> {American Staffordshire Terrier}:  conf = 0.875, sup = 0.157
# {Terrier, American Staffordshire Terrier} ---> {Medium}:  conf = 1.0, sup = 0.157
# {Medium} ---> {Terrier, American Staffordshire Terrier}:  conf = 0.304, sup = 0.157
# {American Staffordshire Terrier} ---> {Terrier, Medium}:  conf = 1.0, sup = 0.157
# {Terrier} ---> {American Staffordshire Terrier, Medium}:  conf = 0.685, sup = 0.157
# {Saver, American Staffordshire Terrier} ---> {Terrier}:  conf = 1.0, sup = 0.157
# {Terrier, American Staffordshire Terrier} ---> {Saver}:  conf = 1.0, sup = 0.157
# {Terrier, Saver} ---> {American Staffordshire Terrier}:  conf = 0.861, sup = 0.157
# {American Staffordshire Terrier} ---> {Terrier, Saver}:  conf = 1.0, sup = 0.157
# {Saver} ---> {Terrier, American Staffordshire Terrier}:  conf = 0.326, sup = 0.157
# {Terrier} ---> {Saver, American Staffordshire Terrier}:  conf = 0.685, sup = 0.157
# {American Staffordshire Terrier, Medium} ---> {Saver}:  conf = 1.0, sup = 0.157
# {Saver, Medium} ---> {American Staffordshire Terrier}:  conf = 0.634, sup = 0.157
# {Saver, American Staffordshire Terrier} ---> {Medium}:  conf = 1.0, sup = 0.157
# {Medium} ---> {Saver, American Staffordshire Terrier}:  conf = 0.304, sup = 0.157
# {American Staffordshire Terrier} ---> {Saver, Medium}:  conf = 1.0, sup = 0.157
# {Saver} ---> {American Staffordshire Terrier, Medium}:  conf = 0.326, sup = 0.157
# {American Staffordshire Terrier, Stray} ---> {Terrier}:  conf = 1.0, sup = 0.103
# {Terrier, Stray} ---> {American Staffordshire Terrier}:  conf = 0.668, sup = 0.103
# {Terrier, American Staffordshire Terrier} ---> {Stray}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier} ---> {Terrier, Stray}:  conf = 0.651, sup = 0.103
# {Terrier} ---> {American Staffordshire Terrier, Stray}:  conf = 0.446, sup = 0.103
# {Stray, Medium} ---> {American Staffordshire Terrier}:  conf = 0.293, sup = 0.103
# {American Staffordshire Terrier, Medium} ---> {Stray}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier, Stray} ---> {Medium}:  conf = 1.0, sup = 0.103
# {American Staffordshire Terrier} ---> {Stray, Medium}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier, Stray} ---> {Saver}:  conf = 1.0, sup = 0.103
# {Saver, Stray} ---> {American Staffordshire Terrier}:  conf = 0.315, sup = 0.103
# {Saver, American Staffordshire Terrier} ---> {Stray}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier} ---> {Saver, Stray}:  conf = 0.651, sup = 0.103
# {Saver} ---> {American Staffordshire Terrier, Stray}:  conf = 0.212, sup = 0.103
# {American Staffordshire Terrier, Above-Average} ---> {Stray}:  conf = 0.651, sup = 0.103
# {Above-Average, Stray} ---> {American Staffordshire Terrier}:  conf = 0.779, sup = 0.103
# {American Staffordshire Terrier, Stray} ---> {Above-Average}:  conf = 1.0, sup = 0.103
# {Above-Average} ---> {American Staffordshire Terrier, Stray}:  conf = 0.516, sup = 0.103
# {American Staffordshire Terrier} ---> {Above-Average, Stray}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier, Above-Average} ---> {Saver}:  conf = 1.0, sup = 0.157
# {Saver, Above-Average} ---> {American Staffordshire Terrier}:  conf = 0.948, sup = 0.157
# {Saver, American Staffordshire Terrier} ---> {Above-Average}:  conf = 1.0, sup = 0.157
# {Above-Average} ---> {Saver, American Staffordshire Terrier}:  conf = 0.792, sup = 0.157
# {American Staffordshire Terrier} ---> {Saver, Above-Average}:  conf = 1.0, sup = 0.157
# {Saver} ---> {American Staffordshire Terrier, Above-Average}:  conf = 0.326, sup = 0.157
# {Saver, Stray} ---> {Terrier}:  conf = 0.37, sup = 0.121
# {Terrier, Stray} ---> {Saver}:  conf = 0.785, sup = 0.121
# {Terrier, Saver} ---> {Stray}:  conf = 0.659, sup = 0.121
# {Saver} ---> {Terrier, Stray}:  conf = 0.25, sup = 0.121
# {Terrier} ---> {Saver, Stray}:  conf = 0.524, sup = 0.121
# {Above-Average, Stray} ---> {Terrier}:  conf = 0.883, sup = 0.116
# {Terrier, Stray} ---> {Above-Average}:  conf = 0.757, sup = 0.116
# {Terrier, Above-Average} ---> {Stray}:  conf = 0.661, sup = 0.116
# {Above-Average} ---> {Terrier, Stray}:  conf = 0.585, sup = 0.116
# {Terrier} ---> {Above-Average, Stray}:  conf = 0.506, sup = 0.116
# {Saver, Above-Average} ---> {Terrier}:  conf = 0.953, sup = 0.158
# {Terrier, Above-Average} ---> {Saver}:  conf = 0.9, sup = 0.158
# {Terrier, Saver} ---> {Above-Average}:  conf = 0.865, sup = 0.158
# {Above-Average} ---> {Terrier, Saver}:  conf = 0.796, sup = 0.158
# {Saver} ---> {Terrier, Above-Average}:  conf = 0.328, sup = 0.158
# {Terrier} ---> {Saver, Above-Average}:  conf = 0.689, sup = 0.158
# {American Staffordshire Terrier, Above-Average} ---> {Terrier}:  conf = 1.0, sup = 0.157
# {Terrier, Above-Average} ---> {American Staffordshire Terrier}:  conf = 0.895, sup = 0.157
# {Terrier, American Staffordshire Terrier} ---> {Above-Average}:  conf = 1.0, sup = 0.157
# {Above-Average} ---> {Terrier, American Staffordshire Terrier}:  conf = 0.792, sup = 0.157
# {American Staffordshire Terrier} ---> {Terrier, Above-Average}:  conf = 1.0, sup = 0.157
# {Terrier} ---> {American Staffordshire Terrier, Above-Average}:  conf = 0.685, sup = 0.157
# {Stray, Medium} ---> {Above-Average}:  conf = 0.3, sup = 0.105
# {Above-Average, Medium} ---> {Stray}:  conf = 0.651, sup = 0.105
# {Above-Average, Stray} ---> {Medium}:  conf = 0.798, sup = 0.105
# {Medium} ---> {Above-Average, Stray}:  conf = 0.203, sup = 0.105
# {Above-Average} ---> {Stray, Medium}:  conf = 0.529, sup = 0.105
# {Above-Average, Medium} ---> {Saver}:  conf = 0.99, sup = 0.16
# {Saver, Medium} ---> {Above-Average}:  conf = 0.644, sup = 0.16
# {Saver, Above-Average} ---> {Medium}:  conf = 0.963, sup = 0.16
# {Medium} ---> {Saver, Above-Average}:  conf = 0.308, sup = 0.16
# {Above-Average} ---> {Saver, Medium}:  conf = 0.804, sup = 0.16
# {Saver} ---> {Above-Average, Medium}:  conf = 0.331, sup = 0.16
# {Above-Average, Medium} ---> {American Staffordshire Terrier}:  conf = 0.975, sup = 0.157
# {American Staffordshire Terrier, Medium} ---> {Above-Average}:  conf = 1.0, sup = 0.157
# {American Staffordshire Terrier, Above-Average} ---> {Medium}:  conf = 1.0, sup = 0.157
# {Medium} ---> {American Staffordshire Terrier, Above-Average}:  conf = 0.304, sup = 0.157
# {Above-Average} ---> {American Staffordshire Terrier, Medium}:  conf = 0.792, sup = 0.157
# {American Staffordshire Terrier} ---> {Above-Average, Medium}:  conf = 1.0, sup = 0.157
# {Above-Average, Medium} ---> {Terrier}:  conf = 0.979, sup = 0.158
# {Terrier, Medium} ---> {Above-Average}:  conf = 0.878, sup = 0.158
# {Terrier, Above-Average} ---> {Medium}:  conf = 0.898, sup = 0.158
# {Medium} ---> {Terrier, Above-Average}:  conf = 0.305, sup = 0.158
# {Above-Average} ---> {Terrier, Medium}:  conf = 0.794, sup = 0.158
# {Terrier} ---> {Above-Average, Medium}:  conf = 0.687, sup = 0.158
# {Female, Medium} ---> {Saver}:  conf = 0.484, sup = 0.119
# {Saver, Female} ---> {Medium}:  conf = 0.526, sup = 0.119
# {Saver, Medium} ---> {Female}:  conf = 0.478, sup = 0.119
# {Female} ---> {Saver, Medium}:  conf = 0.256, sup = 0.119
# {Medium} ---> {Saver, Female}:  conf = 0.229, sup = 0.119
# {Saver} ---> {Female, Medium}:  conf = 0.245, sup = 0.119
# {Male, Medium} ---> {Budget}:  conf = 0.441, sup = 0.121
# {Budget, Medium} ---> {Male}:  conf = 0.523, sup = 0.121
# {Budget, Male} ---> {Medium}:  conf = 0.725, sup = 0.121
# {Medium} ---> {Budget, Male}:  conf = 0.233, sup = 0.121
# {Male} ---> {Budget, Medium}:  conf = 0.225, sup = 0.121
# {Budget} ---> {Male, Medium}:  conf = 0.387, sup = 0.121
# {Brightest, Stray} ---> {Male}:  conf = 0.518, sup = 0.113
# {Stray, Male} ---> {Brightest}:  conf = 0.311, sup = 0.113
# {Brightest, Male} ---> {Stray}:  conf = 0.682, sup = 0.113
# {Brightest} ---> {Stray, Male}:  conf = 0.356, sup = 0.113
# {Male} ---> {Brightest, Stray}:  conf = 0.212, sup = 0.113
# {Male, True} ---> {Stray}:  conf = 0.685, sup = 0.174
# {Stray, True} ---> {Male}:  conf = 0.518, sup = 0.174
# {Male, Stray} ---> {True}:  conf = 0.476, sup = 0.174
# {True} ---> {Male, Stray}:  conf = 0.353, sup = 0.174
# {Male} ---> {Stray, True}:  conf = 0.324, sup = 0.174
# {Stray} ---> {Male, True}:  conf = 0.255, sup = 0.174
# {Male, Medium} ---> {Stray}:  conf = 0.672, sup = 0.184
# {Stray, Medium} ---> {Male}:  conf = 0.524, sup = 0.184
# {Male, Stray} ---> {Medium}:  conf = 0.503, sup = 0.184
# {Medium} ---> {Male, Stray}:  conf = 0.354, sup = 0.184
# {Male} ---> {Stray, Medium}:  conf = 0.343, sup = 0.184
# {Stray} ---> {Male, Medium}:  conf = 0.27, sup = 0.184
# {Medium, True} ---> {Male}:  conf = 0.5, sup = 0.128
# {Male, True} ---> {Medium}:  conf = 0.507, sup = 0.128
# {Male, Medium} ---> {True}:  conf = 0.47, sup = 0.128
# {True} ---> {Male, Medium}:  conf = 0.261, sup = 0.128
# {Medium} ---> {Male, True}:  conf = 0.248, sup = 0.128
# {Male} ---> {Medium, True}:  conf = 0.24, sup = 0.128
# {Medium, True} ---> {Stray}:  conf = 0.674, sup = 0.173
# {Stray, True} ---> {Medium}:  conf = 0.516, sup = 0.173
# {Stray, Medium} ---> {True}:  conf = 0.494, sup = 0.173
# {True} ---> {Stray, Medium}:  conf = 0.352, sup = 0.173
# {Medium} ---> {Stray, True}:  conf = 0.334, sup = 0.173
# {Stray} ---> {Medium, True}:  conf = 0.254, sup = 0.173
# {Medium, True} ---> {Brightest}:  conf = 0.478, sup = 0.123
# {Brightest, True} ---> {Medium}:  conf = 0.713, sup = 0.123
# {Brightest, Medium} ---> {True}:  conf = 0.541, sup = 0.123
# {True} ---> {Brightest, Medium}:  conf = 0.249, sup = 0.123
# {Medium} ---> {Brightest, True}:  conf = 0.237, sup = 0.123
# {Brightest} ---> {Medium, True}:  conf = 0.385, sup = 0.123
# {Stray, True} ---> {Brightest}:  conf = 0.349, sup = 0.117
# {Brightest, True} ---> {Stray}:  conf = 0.68, sup = 0.117
# {Brightest, Stray} ---> {True}:  conf = 0.534, sup = 0.117
# {True} ---> {Brightest, Stray}:  conf = 0.238, sup = 0.117
# {Brightest} ---> {Stray, True}:  conf = 0.367, sup = 0.117
# {Stray, True} ---> {Budget}:  conf = 0.319, sup = 0.107
# {Budget, True} ---> {Stray}:  conf = 0.69, sup = 0.107
# {Budget, Stray} ---> {True}:  conf = 0.491, sup = 0.107
# {True} ---> {Budget, Stray}:  conf = 0.217, sup = 0.107
# {Budget} ---> {Stray, True}:  conf = 0.343, sup = 0.107
# {Medium, True} ---> {Budget}:  conf = 0.473, sup = 0.121
# {Budget, True} ---> {Medium}:  conf = 0.784, sup = 0.121
# {Budget, Medium} ---> {True}:  conf = 0.526, sup = 0.121
# {True} ---> {Budget, Medium}:  conf = 0.247, sup = 0.121
# {Medium} ---> {Budget, True}:  conf = 0.234, sup = 0.121
# {Budget} ---> {Medium, True}:  conf = 0.39, sup = 0.121
# {Stray, Medium} ---> {Terrier}:  conf = 0.335, sup = 0.117
# {Terrier, Medium} ---> {Stray}:  conf = 0.652, sup = 0.117
# {Terrier, Stray} ---> {Medium}:  conf = 0.764, sup = 0.117
# {Medium} ---> {Terrier, Stray}:  conf = 0.226, sup = 0.117
# {Terrier} ---> {Stray, Medium}:  conf = 0.511, sup = 0.117
# {Male, Stray} ---> {Saver}:  conf = 0.474, sup = 0.173
# {Saver, Male} ---> {Stray}:  conf = 0.672, sup = 0.173
# {Saver, Stray} ---> {Male}:  conf = 0.531, sup = 0.173
# {Male} ---> {Saver, Stray}:  conf = 0.323, sup = 0.173
# {Stray} ---> {Saver, Male}:  conf = 0.254, sup = 0.173
# {Saver} ---> {Male, Stray}:  conf = 0.358, sup = 0.173
# {Above-Average, Stray} ---> {Saver}:  conf = 0.823, sup = 0.108
# {Saver, Stray} ---> {Above-Average}:  conf = 0.333, sup = 0.108
# {Saver, Above-Average} ---> {Stray}:  conf = 0.653, sup = 0.108
# {Above-Average} ---> {Saver, Stray}:  conf = 0.545, sup = 0.108
# {Saver} ---> {Above-Average, Stray}:  conf = 0.224, sup = 0.108
# {Saver, Stray} ---> {False}:  conf = 0.511, sup = 0.167
# {False, Stray} ---> {Saver}:  conf = 0.481, sup = 0.167
# {False, Saver} ---> {Stray}:  conf = 0.676, sup = 0.167
# {Stray} ---> {False, Saver}:  conf = 0.244, sup = 0.167
# {Saver} ---> {False, Stray}:  conf = 0.345, sup = 0.167
# {False} ---> {Saver, Stray}:  conf = 0.328, sup = 0.167
# {Saver, Female} ---> {False}:  conf = 0.483, sup = 0.109
# {False, Female} ---> {Saver}:  conf = 0.484, sup = 0.109
# {False, Saver} ---> {Female}:  conf = 0.442, sup = 0.109
# {Female} ---> {False, Saver}:  conf = 0.235, sup = 0.109
# {Saver} ---> {False, Female}:  conf = 0.225, sup = 0.109
# {False} ---> {Saver, Female}:  conf = 0.215, sup = 0.109
# {Brightest, Stray} ---> {Saver}:  conf = 0.469, sup = 0.103
# {Saver, Stray} ---> {Brightest}:  conf = 0.316, sup = 0.103
# {Saver, Brightest} ---> {Stray}:  conf = 0.675, sup = 0.103
# {Brightest} ---> {Saver, Stray}:  conf = 0.323, sup = 0.103
# {Saver} ---> {Brightest, Stray}:  conf = 0.213, sup = 0.103
# {Stray, Female} ---> {Saver}:  conf = 0.483, sup = 0.153
# {Saver, Female} ---> {Stray}:  conf = 0.677, sup = 0.153
# {Saver, Stray} ---> {Female}:  conf = 0.469, sup = 0.153
# {Female} ---> {Saver, Stray}:  conf = 0.329, sup = 0.153
# {Stray} ---> {Saver, Female}:  conf = 0.224, sup = 0.153
# {Saver} ---> {Stray, Female}:  conf = 0.316, sup = 0.153
# {Male, Medium} ---> {Brightest}:  conf = 0.427, sup = 0.117
# {Brightest, Medium} ---> {Male}:  conf = 0.516, sup = 0.117
# {Brightest, Male} ---> {Medium}:  conf = 0.703, sup = 0.117
# {Medium} ---> {Brightest, Male}:  conf = 0.226, sup = 0.117
# {Male} ---> {Brightest, Medium}:  conf = 0.218, sup = 0.117
# {Brightest} ---> {Male, Medium}:  conf = 0.367, sup = 0.117
# {Male, Medium} ---> {False}:  conf = 0.53, sup = 0.145
# {False, Medium} ---> {Male}:  conf = 0.554, sup = 0.145
# {False, Male} ---> {Medium}:  conf = 0.513, sup = 0.145
# {Medium} ---> {False, Male}:  conf = 0.28, sup = 0.145
# {Male} ---> {False, Medium}:  conf = 0.271, sup = 0.145
# {False} ---> {Male, Medium}:  conf = 0.286, sup = 0.145
# {Saver, Medium} ---> {False}:  conf = 0.528, sup = 0.131
# {False, Medium} ---> {Saver}:  conf = 0.501, sup = 0.131
# {False, Saver} ---> {Medium}:  conf = 0.532, sup = 0.131
# {Medium} ---> {False, Saver}:  conf = 0.253, sup = 0.131
# {Saver} ---> {False, Medium}:  conf = 0.271, sup = 0.131
# {False} ---> {Saver, Medium}:  conf = 0.258, sup = 0.131
# {Male, Medium} ---> {Saver}:  conf = 0.474, sup = 0.13
# {Saver, Medium} ---> {Male}:  conf = 0.522, sup = 0.13
# {Saver, Male} ---> {Medium}:  conf = 0.503, sup = 0.13
# {Medium} ---> {Saver, Male}:  conf = 0.25, sup = 0.13
# {Male} ---> {Saver, Medium}:  conf = 0.242, sup = 0.13
# {Saver} ---> {Male, Medium}:  conf = 0.268, sup = 0.13
# {Male, True} ---> {Saver}:  conf = 0.474, sup = 0.12
# {Saver, True} ---> {Male}:  conf = 0.507, sup = 0.12
# {Saver, Male} ---> {True}:  conf = 0.466, sup = 0.12
# {True} ---> {Saver, Male}:  conf = 0.244, sup = 0.12
# {Male} ---> {Saver, True}:  conf = 0.224, sup = 0.12
# {Saver} ---> {Male, True}:  conf = 0.249, sup = 0.12
# {Small, Male} ---> {Stray}:  conf = 0.704, sup = 0.111
# {Male, Stray} ---> {Small}:  conf = 0.303, sup = 0.111
# {Small, Stray} ---> {Male}:  conf = 0.554, sup = 0.111
# {Male} ---> {Small, Stray}:  conf = 0.207, sup = 0.111
# {Small} ---> {Male, Stray}:  conf = 0.384, sup = 0.111
# {Small, Stray} ---> {False}:  conf = 0.54, sup = 0.108
# {False, Stray} ---> {Small}:  conf = 0.312, sup = 0.108
# {False, Small} ---> {Stray}:  conf = 0.685, sup = 0.108
# {Small} ---> {False, Stray}:  conf = 0.374, sup = 0.108
# {False} ---> {Small, Stray}:  conf = 0.213, sup = 0.108
# {Brightest, Medium} ---> {False}:  conf = 0.459, sup = 0.104
# {False, Medium} ---> {Brightest}:  conf = 0.398, sup = 0.104
# {False, Brightest} ---> {Medium}:  conf = 0.712, sup = 0.104
# {Medium} ---> {False, Brightest}:  conf = 0.201, sup = 0.104
# {Brightest} ---> {False, Medium}:  conf = 0.327, sup = 0.104
# {False} ---> {Brightest, Medium}:  conf = 0.205, sup = 0.104
# {Stray, Medium} ---> {Sporting}:  conf = 0.3, sup = 0.105
# {Sporting, Medium} ---> {Stray}:  conf = 0.693, sup = 0.105
# {Sporting, Stray} ---> {Medium}:  conf = 0.889, sup = 0.105
# {Medium} ---> {Sporting, Stray}:  conf = 0.203, sup = 0.105
# {Sporting} ---> {Stray, Medium}:  conf = 0.614, sup = 0.105
# {Stray, Medium} ---> {False}:  conf = 0.506, sup = 0.177
# {False, Medium} ---> {Stray}:  conf = 0.677, sup = 0.177
# {False, Stray} ---> {Medium}:  conf = 0.512, sup = 0.177
# {Medium} ---> {False, Stray}:  conf = 0.342, sup = 0.177
# {Stray} ---> {False, Medium}:  conf = 0.26, sup = 0.177
# {False} ---> {Stray, Medium}:  conf = 0.349, sup = 0.177
# {Sporting, Medium} ---> {Budget}:  conf = 0.972, sup = 0.148
# {Budget, Medium} ---> {Sporting}:  conf = 0.64, sup = 0.148
# {Budget, Sporting} ---> {Medium}:  conf = 0.964, sup = 0.148
# {Medium} ---> {Budget, Sporting}:  conf = 0.285, sup = 0.148
# {Sporting} ---> {Budget, Medium}:  conf = 0.862, sup = 0.148
# {Budget} ---> {Sporting, Medium}:  conf = 0.474, sup = 0.148
# {Budget, Medium} ---> {False}:  conf = 0.474, sup = 0.109
# {False, Medium} ---> {Budget}:  conf = 0.418, sup = 0.109
# {False, Budget} ---> {Medium}:  conf = 0.699, sup = 0.109
# {Medium} ---> {False, Budget}:  conf = 0.211, sup = 0.109
# {Budget} ---> {False, Medium}:  conf = 0.351, sup = 0.109
# {False} ---> {Budget, Medium}:  conf = 0.216, sup = 0.109
# {Stray, Medium} ---> {Budget}:  conf = 0.459, sup = 0.161
# {Budget, Medium} ---> {Stray}:  conf = 0.697, sup = 0.161
# {Budget, Stray} ---> {Medium}:  conf = 0.74, sup = 0.161
# {Medium} ---> {Budget, Stray}:  conf = 0.31, sup = 0.161
# {Stray} ---> {Budget, Medium}:  conf = 0.236, sup = 0.161
# {Budget} ---> {Stray, Medium}:  conf = 0.516, sup = 0.161
# {Brightest, Labrador Retriever} ---> {Medium}:  conf = 1.0, sup = 0.141
# {Labrador Retriever, Medium} ---> {Brightest}:  conf = 1.0, sup = 0.141
# {Brightest, Medium} ---> {Labrador Retriever}:  conf = 0.622, sup = 0.141
# {Labrador Retriever} ---> {Brightest, Medium}:  conf = 1.0, sup = 0.141
# {Brightest} ---> {Labrador Retriever, Medium}:  conf = 0.443, sup = 0.141
# {Medium} ---> {Brightest, Labrador Retriever}:  conf = 0.272, sup = 0.141
# {Sporting, Labrador Retriever} ---> {Medium}:  conf = 1.0, sup = 0.141
# {Labrador Retriever, Medium} ---> {Sporting}:  conf = 1.0, sup = 0.141
# {Sporting, Medium} ---> {Labrador Retriever}:  conf = 0.929, sup = 0.141
# {Labrador Retriever} ---> {Sporting, Medium}:  conf = 1.0, sup = 0.141
# {Sporting} ---> {Labrador Retriever, Medium}:  conf = 0.823, sup = 0.141
# {Medium} ---> {Sporting, Labrador Retriever}:  conf = 0.272, sup = 0.141
# {Sporting, Labrador Retriever} ---> {Budget}:  conf = 1.0, sup = 0.141
# {Budget, Labrador Retriever} ---> {Sporting}:  conf = 1.0, sup = 0.141
# {Budget, Sporting} ---> {Labrador Retriever}:  conf = 0.921, sup = 0.141
# {Labrador Retriever} ---> {Budget, Sporting}:  conf = 1.0, sup = 0.141
# {Sporting} ---> {Budget, Labrador Retriever}:  conf = 0.823, sup = 0.141
# {Budget} ---> {Sporting, Labrador Retriever}:  conf = 0.453, sup = 0.141
# {Labrador Retriever, Medium} ---> {Budget}:  conf = 1.0, sup = 0.141
# {Budget, Labrador Retriever} ---> {Medium}:  conf = 1.0, sup = 0.141
# {Budget, Medium} ---> {Labrador Retriever}:  conf = 0.611, sup = 0.141
# {Labrador Retriever} ---> {Budget, Medium}:  conf = 1.0, sup = 0.141
# {Medium} ---> {Budget, Labrador Retriever}:  conf = 0.272, sup = 0.141
# {Budget} ---> {Labrador Retriever, Medium}:  conf = 0.453, sup = 0.141
# {Brightest, Female} ---> {Medium}:  conf = 0.722, sup = 0.11
# {Female, Medium} ---> {Brightest}:  conf = 0.449, sup = 0.11
# {Brightest, Medium} ---> {Female}:  conf = 0.484, sup = 0.11
# {Female} ---> {Brightest, Medium}:  conf = 0.237, sup = 0.11
# {Brightest} ---> {Female, Medium}:  conf = 0.345, sup = 0.11
# {Medium} ---> {Brightest, Female}:  conf = 0.212, sup = 0.11
# {Stray, Female} ---> {Medium}:  conf = 0.527, sup = 0.167
# {Female, Medium} ---> {Stray}:  conf = 0.68, sup = 0.167
# {Stray, Medium} ---> {Female}:  conf = 0.476, sup = 0.167
# {Female} ---> {Stray, Medium}:  conf = 0.359, sup = 0.167
# {Stray} ---> {Female, Medium}:  conf = 0.245, sup = 0.167
# {Medium} ---> {Stray, Female}:  conf = 0.321, sup = 0.167
# {Stray, Female} ---> {False}:  conf = 0.489, sup = 0.155
# {False, Female} ---> {Stray}:  conf = 0.687, sup = 0.155
# {False, Stray} ---> {Female}:  conf = 0.447, sup = 0.155
# {Female} ---> {False, Stray}:  conf = 0.334, sup = 0.155
# {Stray} ---> {False, Female}:  conf = 0.227, sup = 0.155
# {False} ---> {Stray, Female}:  conf = 0.305, sup = 0.155
# {Female, Medium} ---> {False}:  conf = 0.476, sup = 0.117
# {False, Female} ---> {Medium}:  conf = 0.518, sup = 0.117
# {False, Medium} ---> {Female}:  conf = 0.446, sup = 0.117
# {Female} ---> {False, Medium}:  conf = 0.252, sup = 0.117
# {Medium} ---> {False, Female}:  conf = 0.225, sup = 0.117
# {False} ---> {Female, Medium}:  conf = 0.23, sup = 0.117
# {Stray, Female} ---> {Budget}:  conf = 0.32, sup = 0.101
# {Budget, Female} ---> {Stray}:  conf = 0.698, sup = 0.101
# {Budget, Stray} ---> {Female}:  conf = 0.465, sup = 0.101
# {Female} ---> {Budget, Stray}:  conf = 0.218, sup = 0.101
# {Budget} ---> {Stray, Female}:  conf = 0.325, sup = 0.101
# {Female, Medium} ---> {Budget}:  conf = 0.45, sup = 0.11
# {Budget, Female} ---> {Medium}:  conf = 0.76, sup = 0.11
# {Budget, Medium} ---> {Female}:  conf = 0.477, sup = 0.11
# {Female} ---> {Budget, Medium}:  conf = 0.238, sup = 0.11
# {Medium} ---> {Budget, Female}:  conf = 0.213, sup = 0.11
# {Budget} ---> {Female, Medium}:  conf = 0.354, sup = 0.11
# {Brightest, Stray} ---> {False}:  conf = 0.466, sup = 0.102
# {False, Stray} ---> {Brightest}:  conf = 0.295, sup = 0.102
# {False, Brightest} ---> {Stray}:  conf = 0.698, sup = 0.102
# {Brightest} ---> {False, Stray}:  conf = 0.321, sup = 0.102
# {False} ---> {Brightest, Stray}:  conf = 0.201, sup = 0.102
# {Stray, Medium} ---> {Brightest}:  conf = 0.447, sup = 0.157
# {Brightest, Medium} ---> {Stray}:  conf = 0.69, sup = 0.157
# {Brightest, Stray} ---> {Medium}:  conf = 0.715, sup = 0.157
# {Medium} ---> {Brightest, Stray}:  conf = 0.302, sup = 0.157
# {Stray} ---> {Brightest, Medium}:  conf = 0.23, sup = 0.157
# {Brightest} ---> {Stray, Medium}:  conf = 0.492, sup = 0.157
# {Stray, Female} ---> {Brightest}:  conf = 0.334, sup = 0.106
# {Brightest, Female} ---> {Stray}:  conf = 0.694, sup = 0.106
# {Brightest, Stray} ---> {Female}:  conf = 0.482, sup = 0.106
# {Female} ---> {Brightest, Stray}:  conf = 0.228, sup = 0.106
# {Brightest} ---> {Stray, Female}:  conf = 0.332, sup = 0.106
# {Brightest, Medium} ---> {Sporting}:  conf = 0.646, sup = 0.147
# {Sporting, Medium} ---> {Brightest}:  conf = 0.964, sup = 0.147
# {Sporting, Brightest} ---> {Medium}:  conf = 1.0, sup = 0.147
# {Medium} ---> {Sporting, Brightest}:  conf = 0.283, sup = 0.147
# {Brightest} ---> {Sporting, Medium}:  conf = 0.46, sup = 0.147
# {Sporting} ---> {Brightest, Medium}:  conf = 0.855, sup = 0.147
# {Brightest, Labrador Retriever} ---> {Sporting}:  conf = 1.0, sup = 0.141
# {Sporting, Labrador Retriever} ---> {Brightest}:  conf = 1.0, sup = 0.141
# {Sporting, Brightest} ---> {Labrador Retriever}:  conf = 0.963, sup = 0.141
# {Labrador Retriever} ---> {Sporting, Brightest}:  conf = 1.0, sup = 0.141
# {Brightest} ---> {Sporting, Labrador Retriever}:  conf = 0.443, sup = 0.141
# {Sporting} ---> {Brightest, Labrador Retriever}:  conf = 0.823, sup = 0.141
# {Brightest, Stray} ---> {Sporting}:  conf = 0.464, sup = 0.102
# {Sporting, Stray} ---> {Brightest}:  conf = 0.859, sup = 0.102
# {Sporting, Brightest} ---> {Stray}:  conf = 0.694, sup = 0.102
# {Brightest} ---> {Sporting, Stray}:  conf = 0.319, sup = 0.102
# {Sporting} ---> {Brightest, Stray}:  conf = 0.593, sup = 0.102
# {Brightest, Medium} ---> {Budget}:  conf = 0.727, sup = 0.165
# {Budget, Medium} ---> {Brightest}:  conf = 0.715, sup = 0.165
# {Budget, Brightest} ---> {Medium}:  conf = 0.993, sup = 0.165
# {Medium} ---> {Budget, Brightest}:  conf = 0.318, sup = 0.165
# {Brightest} ---> {Budget, Medium}:  conf = 0.518, sup = 0.165
# {Budget} ---> {Brightest, Medium}:  conf = 0.53, sup = 0.165
# {Brightest, Labrador Retriever} ---> {Budget}:  conf = 1.0, sup = 0.141
# {Budget, Labrador Retriever} ---> {Brightest}:  conf = 1.0, sup = 0.141
# {Budget, Brightest} ---> {Labrador Retriever}:  conf = 0.849, sup = 0.141
# {Labrador Retriever} ---> {Budget, Brightest}:  conf = 1.0, sup = 0.141
# {Brightest} ---> {Budget, Labrador Retriever}:  conf = 0.443, sup = 0.141
# {Budget} ---> {Brightest, Labrador Retriever}:  conf = 0.453, sup = 0.141
# {Brightest, Stray} ---> {Budget}:  conf = 0.531, sup = 0.116
# {Budget, Stray} ---> {Brightest}:  conf = 0.535, sup = 0.116
# {Budget, Brightest} ---> {Stray}:  conf = 0.7, sup = 0.116
# {Brightest} ---> {Budget, Stray}:  conf = 0.365, sup = 0.116
# {Budget} ---> {Brightest, Stray}:  conf = 0.373, sup = 0.116
# {Sporting, Brightest} ---> {Budget}:  conf = 1.0, sup = 0.147
# {Budget, Brightest} ---> {Sporting}:  conf = 0.882, sup = 0.147
# {Budget, Sporting} ---> {Brightest}:  conf = 0.956, sup = 0.147
# {Brightest} ---> {Budget, Sporting}:  conf = 0.46, sup = 0.147
# {Sporting} ---> {Budget, Brightest}:  conf = 0.855, sup = 0.147
# {Budget} ---> {Sporting, Brightest}:  conf = 0.47, sup = 0.147
# {Saver, Male} ---> {False}:  conf = 0.534, sup = 0.137
# {False, Male} ---> {Saver}:  conf = 0.486, sup = 0.137
# {False, Saver} ---> {Male}:  conf = 0.558, sup = 0.137
# ...
# {Saver, American Staffordshire Terrier, Medium} ---> {Terrier, Above-Average}:  conf = 1.0, sup = 0.157
# {Terrier, American Staffordshire Terrier, Above-Average} ---> {Saver, Medium}:  conf = 1.0, sup = 0.157
# {Terrier, American Staffordshire Terrier, Medium} ---> {Saver, Above-Average}:  conf = 1.0, sup = 0.157
# {Terrier, Saver, American Staffordshire Terrier} ---> {Above-Average, Medium}:  conf = 1.0, sup = 0.157
# {Above-Average, Medium} ---> {Terrier, Saver, American Staffordshire Terrier}:  conf = 0.975, sup = 0.157
# {Saver, Above-Average} ---> {Terrier, American Staffordshire Terrier, Medium}:  conf = 0.948, sup = 0.157
# {Terrier, Above-Average} ---> {Saver, American Staffordshire Terrier, Medium}:  conf = 0.895, sup = 0.157
# {Saver, Medium} ---> {Terrier, American Staffordshire Terrier, Above-Average}:  conf = 0.634, sup = 0.157
# {Terrier, Medium} ---> {Saver, American Staffordshire Terrier, Above-Average}:  conf = 0.875, sup = 0.157
# {Terrier, Saver} ---> {American Staffordshire Terrier, Above-Average, Medium}:  conf = 0.861, sup = 0.157
# {American Staffordshire Terrier, Above-Average} ---> {Terrier, Saver, Medium}:  conf = 1.0, sup = 0.157
# {American Staffordshire Terrier, Medium} ---> {Terrier, Saver, Above-Average}:  conf = 1.0, sup = 0.157
# {Saver, American Staffordshire Terrier} ---> {Terrier, Above-Average, Medium}:  conf = 1.0, sup = 0.157
# {Terrier, American Staffordshire Terrier} ---> {Saver, Above-Average, Medium}:  conf = 1.0, sup = 0.157
# {Above-Average} ---> {American Staffordshire Terrier, Terrier, Saver, Medium}:  conf = 0.792, sup = 0.157
# {Medium} ---> {American Staffordshire Terrier, Above-Average, Terrier, Saver}:  conf = 0.304, sup = 0.157
# {Saver} ---> {American Staffordshire Terrier, Above-Average, Terrier, Medium}:  conf = 0.326, sup = 0.157
# {Terrier} ---> {American Staffordshire Terrier, Above-Average, Saver, Medium}:  conf = 0.685, sup = 0.157
# {American Staffordshire Terrier} ---> {Above-Average, Terrier, Saver, Medium}:  conf = 1.0, sup = 0.157
# {Terrier, Saver, Above-Average, Medium} ---> {Stray}:  conf = 0.651, sup = 0.103
# {Saver, Above-Average, Stray, Medium} ---> {Terrier}:  conf = 0.988, sup = 0.103
# {Terrier, Above-Average, Stray, Medium} ---> {Saver}:  conf = 1.0, sup = 0.103
# {Terrier, Saver, Above-Average, Stray} ---> {Medium}:  conf = 0.997, sup = 0.103
# {Terrier, Saver, Stray, Medium} ---> {Above-Average}:  conf = 0.933, sup = 0.103
# {Saver, Above-Average, Medium} ---> {Terrier, Stray}:  conf = 0.643, sup = 0.103
# {Terrier, Above-Average, Medium} ---> {Saver, Stray}:  conf = 0.651, sup = 0.103
# {Terrier, Saver, Above-Average} ---> {Stray, Medium}:  conf = 0.65, sup = 0.103
# {Terrier, Saver, Medium} ---> {Above-Average, Stray}:  conf = 0.609, sup = 0.103
# {Above-Average, Stray, Medium} ---> {Terrier, Saver}:  conf = 0.978, sup = 0.103
# {Saver, Above-Average, Stray} ---> {Terrier, Medium}:  conf = 0.949, sup = 0.103
# {Saver, Stray, Medium} ---> {Terrier, Above-Average}:  conf = 0.628, sup = 0.103
# {Terrier, Above-Average, Stray} ---> {Saver, Medium}:  conf = 0.885, sup = 0.103
# {Terrier, Stray, Medium} ---> {Saver, Above-Average}:  conf = 0.876, sup = 0.103
# {Terrier, Saver, Stray} ---> {Above-Average, Medium}:  conf = 0.853, sup = 0.103
# {Above-Average, Medium} ---> {Terrier, Saver, Stray}:  conf = 0.637, sup = 0.103
# {Saver, Above-Average} ---> {Terrier, Stray, Medium}:  conf = 0.619, sup = 0.103
# {Terrier, Above-Average} ---> {Saver, Stray, Medium}:  conf = 0.585, sup = 0.103
# {Saver, Medium} ---> {Terrier, Above-Average, Stray}:  conf = 0.414, sup = 0.103
# {Terrier, Medium} ---> {Saver, Above-Average, Stray}:  conf = 0.572, sup = 0.103
# {Terrier, Saver} ---> {Above-Average, Stray, Medium}:  conf = 0.562, sup = 0.103
# {Above-Average, Stray} ---> {Terrier, Saver, Medium}:  conf = 0.781, sup = 0.103
# {Stray, Medium} ---> {Terrier, Saver, Above-Average}:  conf = 0.294, sup = 0.103
# {Saver, Stray} ---> {Terrier, Above-Average, Medium}:  conf = 0.316, sup = 0.103
# {Terrier, Stray} ---> {Saver, Above-Average, Medium}:  conf = 0.67, sup = 0.103
# {Above-Average} ---> {Stray, Terrier, Saver, Medium}:  conf = 0.517, sup = 0.103
# {Saver} ---> {Above-Average, Stray, Terrier, Medium}:  conf = 0.213, sup = 0.103
# {Terrier} ---> {Above-Average, Stray, Saver, Medium}:  conf = 0.447, sup = 0.103
# {Sporting, Brightest, Stray, Medium} ---> {Budget}:  conf = 1.0, sup = 0.102
# {Budget, Sporting, Brightest, Medium} ---> {Stray}:  conf = 0.694, sup = 0.102
# {Budget, Sporting, Stray, Medium} ---> {Brightest}:  conf = 0.992, sup = 0.102
# {Budget, Sporting, Brightest, Stray} ---> {Medium}:  conf = 1.0, sup = 0.102
# {Budget, Brightest, Stray, Medium} ---> {Sporting}:  conf = 0.881, sup = 0.102
# {Sporting, Brightest, Medium} ---> {Budget, Stray}:  conf = 0.694, sup = 0.102
# {Sporting, Stray, Medium} ---> {Budget, Brightest}:  conf = 0.966, sup = 0.102
# {Sporting, Brightest, Stray} ---> {Budget, Medium}:  conf = 1.0, sup = 0.102
# {Brightest, Stray, Medium} ---> {Budget, Sporting}:  conf = 0.649, sup = 0.102
# {Budget, Sporting, Medium} ---> {Brightest, Stray}:  conf = 0.688, sup = 0.102
# {Budget, Sporting, Brightest} ---> {Stray, Medium}:  conf = 0.694, sup = 0.102
# {Budget, Brightest, Medium} ---> {Sporting, Stray}:  conf = 0.616, sup = 0.102
# {Budget, Sporting, Stray} ---> {Brightest, Medium}:  conf = 0.957, sup = 0.102
# {Budget, Stray, Medium} ---> {Sporting, Brightest}:  conf = 0.632, sup = 0.102
# {Budget, Brightest, Stray} ---> {Sporting, Medium}:  conf = 0.874, sup = 0.102
# {Sporting, Brightest} ---> {Budget, Stray, Medium}:  conf = 0.694, sup = 0.102
# {Brightest, Medium} ---> {Budget, Sporting, Stray}:  conf = 0.448, sup = 0.102
# {Sporting, Medium} ---> {Budget, Brightest, Stray}:  conf = 0.669, sup = 0.102
# {Sporting, Stray} ---> {Budget, Brightest, Medium}:  conf = 0.859, sup = 0.102
# {Stray, Medium} ---> {Budget, Sporting, Brightest}:  conf = 0.29, sup = 0.102
# {Brightest, Stray} ---> {Budget, Sporting, Medium}:  conf = 0.464, sup = 0.102
# {Budget, Sporting} ---> {Brightest, Stray, Medium}:  conf = 0.663, sup = 0.102
# {Budget, Medium} ---> {Sporting, Brightest, Stray}:  conf = 0.44, sup = 0.102
# {Budget, Brightest} ---> {Sporting, Stray, Medium}:  conf = 0.612, sup = 0.102
# {Budget, Stray} ---> {Sporting, Brightest, Medium}:  conf = 0.467, sup = 0.102
# {Brightest} ---> {Budget, Stray, Sporting, Medium}:  conf = 0.319, sup = 0.102
# {Sporting} ---> {Budget, Stray, Brightest, Medium}:  conf = 0.593, sup = 0.102
# {Budget} ---> {Stray, Sporting, Brightest, Medium}:  conf = 0.326, sup = 0.102
# {Sporting, Medium, Brightest, Labrador Retriever} ---> {Budget}:  conf = 1.0, sup = 0.141
# {Budget, Sporting, Brightest, Medium} ---> {Labrador Retriever}:  conf = 0.963, sup = 0.141
# {Budget, Sporting, Medium, Labrador Retriever} ---> {Brightest}:  conf = 1.0, sup = 0.141
# {Budget, Sporting, Brightest, Labrador Retriever} ---> {Medium}:  conf = 1.0, sup = 0.141
# {Budget, Medium, Brightest, Labrador Retriever} ---> {Sporting}:  conf = 1.0, sup = 0.141
# {Sporting, Brightest, Medium} ---> {Budget, Labrador Retriever}:  conf = 0.963, sup = 0.141
# {Sporting, Medium, Labrador Retriever} ---> {Budget, Brightest}:  conf = 1.0, sup = 0.141
# {Sporting, Brightest, Labrador Retriever} ---> {Budget, Medium}:  conf = 1.0, sup = 0.141
# {Medium, Brightest, Labrador Retriever} ---> {Budget, Sporting}:  conf = 1.0, sup = 0.141
# {Budget, Sporting, Medium} ---> {Brightest, Labrador Retriever}:  conf = 0.956, sup = 0.141
# {Budget, Sporting, Brightest} ---> {Medium, Labrador Retriever}:  conf = 0.963, sup = 0.141
# {Budget, Brightest, Medium} ---> {Sporting, Labrador Retriever}:  conf = 0.855, sup = 0.141
# {Budget, Sporting, Labrador Retriever} ---> {Brightest, Medium}:  conf = 1.0, sup = 0.141
# {Budget, Medium, Labrador Retriever} ---> {Sporting, Brightest}:  conf = 1.0, sup = 0.141
# {Budget, Brightest, Labrador Retriever} ---> {Sporting, Medium}:  conf = 1.0, sup = 0.141
# {Sporting, Brightest} ---> {Budget, Medium, Labrador Retriever}:  conf = 0.963, sup = 0.141
# {Brightest, Medium} ---> {Budget, Sporting, Labrador Retriever}:  conf = 0.622, sup = 0.141
# {Sporting, Medium} ---> {Budget, Brightest, Labrador Retriever}:  conf = 0.929, sup = 0.141
# {Sporting, Labrador Retriever} ---> {Budget, Brightest, Medium}:  conf = 1.0, sup = 0.141
# {Medium, Labrador Retriever} ---> {Budget, Sporting, Brightest}:  conf = 1.0, sup = 0.141
# {Brightest, Labrador Retriever} ---> {Budget, Sporting, Medium}:  conf = 1.0, sup = 0.141
# {Budget, Sporting} ---> {Medium, Brightest, Labrador Retriever}:  conf = 0.921, sup = 0.141
# {Budget, Medium} ---> {Sporting, Brightest, Labrador Retriever}:  conf = 0.611, sup = 0.141
# {Budget, Brightest} ---> {Sporting, Medium, Labrador Retriever}:  conf = 0.849, sup = 0.141
# {Budget, Labrador Retriever} ---> {Sporting, Brightest, Medium}:  conf = 1.0, sup = 0.141
# {Brightest} ---> {Budget, Labrador Retriever, Sporting, Medium}:  conf = 0.443, sup = 0.141
# {Sporting} ---> {Budget, Labrador Retriever, Brightest, Medium}:  conf = 0.823, sup = 0.141
# {Medium} ---> {Budget, Labrador Retriever, Sporting, Brightest}:  conf = 0.272, sup = 0.141
# {Labrador Retriever} ---> {Budget, Sporting, Brightest, Medium}:  conf = 1.0, sup = 0.141
# {Budget} ---> {Labrador Retriever, Sporting, Brightest, Medium}:  conf = 0.453, sup = 0.141
# {Stray, Terrier, Saver, Medium, Above-Average} ---> {American Staffordshire Terrier}:  conf = 0.997, sup = 0.103
# {American Staffordshire Terrier, Terrier, Saver, Medium, Above-Average} ---> {Stray}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier, Stray, Saver, Medium, Above-Average} ---> {Terrier}:  conf = 1.0, sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Medium, Above-Average} ---> {Saver}:  conf = 1.0, sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Saver, Above-Average} ---> {Medium}:  conf = 1.0, sup = 0.103
# {American Staffordshire Terrier, Stray, Terrier, Saver, Medium} ---> {Above-Average}:  conf = 1.0, sup = 0.103
# {Terrier, Saver, Above-Average, Medium} ---> {American Staffordshire Terrier, Stray}:  conf = 0.649, sup = 0.103
# {Saver, Above-Average, Stray, Medium} ---> {Terrier, American Staffordshire Terrier}:  conf = 0.985, sup = 0.103
# {Terrier, Above-Average, Stray, Medium} ---> {Saver, American Staffordshire Terrier}:  conf = 0.997, sup = 0.103
# {Terrier, Saver, Above-Average, Stray} ---> {American Staffordshire Terrier, Medium}:  conf = 0.995, sup = 0.103
# {Terrier, Saver, Stray, Medium} ---> {American Staffordshire Terrier, Above-Average}:  conf = 0.931, sup = 0.103
# {Saver, American Staffordshire Terrier, Above-Average, Medium} ---> {Terrier, Stray}:  conf = 0.651, sup = 0.103
# {Terrier, American Staffordshire Terrier, Above-Average, Medium} ---> {Saver, Stray}:  conf = 0.651, sup = 0.103
# {Terrier, Saver, American Staffordshire Terrier, Above-Average} ---> {Stray, Medium}:  conf = 0.651, sup = 0.103
# {Terrier, Saver, American Staffordshire Terrier, Medium} ---> {Above-Average, Stray}:  conf = 0.651, sup = 0.103
# {Above-Average, American Staffordshire Terrier, Stray, Medium} ---> {Terrier, Saver}:  conf = 1.0, sup = 0.103
# {Saver, Above-Average, American Staffordshire Terrier, Stray} ---> {Terrier, Medium}:  conf = 1.0, sup = 0.103
# {Saver, American Staffordshire Terrier, Stray, Medium} ---> {Terrier, Above-Average}:  conf = 1.0, sup = 0.103
# {Terrier, Above-Average, American Staffordshire Terrier, Stray} ---> {Saver, Medium}:  conf = 1.0, sup = 0.103
# {Terrier, American Staffordshire Terrier, Stray, Medium} ---> {Saver, Above-Average}:  conf = 1.0, sup = 0.103
# {Terrier, Saver, American Staffordshire Terrier, Stray} ---> {Above-Average, Medium}:  conf = 1.0, sup = 0.103
# {Saver, Above-Average, Medium} ---> {Terrier, American Staffordshire Terrier, Stray}:  conf = 0.642, sup = 0.103
# {Terrier, Above-Average, Medium} ---> {Saver, American Staffordshire Terrier, Stray}:  conf = 0.649, sup = 0.103
# {Terrier, Saver, Above-Average} ---> {American Staffordshire Terrier, Stray, Medium}:  conf = 0.648, sup = 0.103
# {Above-Average, Stray, Medium} ---> {Terrier, Saver, American Staffordshire Terrier}:  conf = 0.976, sup = 0.103
# {Saver, Above-Average, Stray} ---> {Terrier, American Staffordshire Terrier, Medium}:  conf = 0.946, sup = 0.103
# {Terrier, Above-Average, Stray} ---> {Saver, American Staffordshire Terrier, Medium}:  conf = 0.882, sup = 0.103
# {Terrier, Saver, Medium} ---> {Stray, American Staffordshire Terrier, Above-Average}:  conf = 0.607, sup = 0.103
# {Saver, Stray, Medium} ---> {Terrier, American Staffordshire Terrier, Above-Average}:  conf = 0.626, sup = 0.103
# {Terrier, Stray, Medium} ---> {Saver, American Staffordshire Terrier, Above-Average}:  conf = 0.874, sup = 0.103
# {Terrier, Saver, Stray} ---> {American Staffordshire Terrier, Above-Average, Medium}:  conf = 0.851, sup = 0.103
# {American Staffordshire Terrier, Above-Average, Medium} ---> {Terrier, Saver, Stray}:  conf = 0.651, sup = 0.103
# {Saver, American Staffordshire Terrier, Above-Average} ---> {Terrier, Stray, Medium}:  conf = 0.651, sup = 0.103
# {Terrier, American Staffordshire Terrier, Above-Average} ---> {Saver, Stray, Medium}:  conf = 0.651, sup = 0.103
# {Saver, American Staffordshire Terrier, Medium} ---> {Terrier, Above-Average, Stray}:  conf = 0.651, sup = 0.103
# {Terrier, American Staffordshire Terrier, Medium} ---> {Saver, Above-Average, Stray}:  conf = 0.651, sup = 0.103
# {Terrier, Saver, American Staffordshire Terrier} ---> {Above-Average, Stray, Medium}:  conf = 0.651, sup = 0.103
# {Above-Average, American Staffordshire Terrier, Stray} ---> {Terrier, Saver, Medium}:  conf = 1.0, sup = 0.103
# {American Staffordshire Terrier, Stray, Medium} ---> {Terrier, Saver, Above-Average}:  conf = 1.0, sup = 0.103
# {Saver, American Staffordshire Terrier, Stray} ---> {Terrier, Above-Average, Medium}:  conf = 1.0, sup = 0.103
# {Terrier, American Staffordshire Terrier, Stray} ---> {Saver, Above-Average, Medium}:  conf = 1.0, sup = 0.103
# {Above-Average, Medium} ---> {American Staffordshire Terrier, Stray, Terrier, Saver}:  conf = 0.635, sup = 0.103
# {Saver, Above-Average} ---> {American Staffordshire Terrier, Stray, Terrier, Medium}:  conf = 0.618, sup = 0.103
# {Terrier, Above-Average} ---> {American Staffordshire Terrier, Stray, Saver, Medium}:  conf = 0.583, sup = 0.103
# {Above-Average, Stray} ---> {American Staffordshire Terrier, Terrier, Saver, Medium}:  conf = 0.779, sup = 0.103
# {Saver, Medium} ---> {American Staffordshire Terrier, Stray, Above-Average, Terrier}:  conf = 0.413, sup = 0.103
# {Terrier, Medium} ---> {American Staffordshire Terrier, Stray, Above-Average, Saver}:  conf = 0.57, sup = 0.103
# {Terrier, Saver} ---> {American Staffordshire Terrier, Stray, Above-Average, Medium}:  conf = 0.561, sup = 0.103
# {Stray, Medium} ---> {American Staffordshire Terrier, Above-Average, Terrier, Saver}:  conf = 0.293, sup = 0.103
# {Saver, Stray} ---> {American Staffordshire Terrier, Above-Average, Terrier, Medium}:  conf = 0.315, sup = 0.103
# {Terrier, Stray} ---> {American Staffordshire Terrier, Above-Average, Saver, Medium}:  conf = 0.668, sup = 0.103
# {American Staffordshire Terrier, Above-Average} ---> {Stray, Terrier, Saver, Medium}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier, Medium} ---> {Above-Average, Stray, Terrier, Saver}:  conf = 0.651, sup = 0.103
# {Saver, American Staffordshire Terrier} ---> {Above-Average, Stray, Terrier, Medium}:  conf = 0.651, sup = 0.103
# {Terrier, American Staffordshire Terrier} ---> {Above-Average, Stray, Saver, Medium}:  conf = 0.651, sup = 0.103
# {American Staffordshire Terrier, Stray} ---> {Above-Average, Terrier, Saver, Medium}:  conf = 1.0, sup = 0.103
# {Above-Average} ---> {American Staffordshire Terrier, Stray, Terrier, Saver, Medium}:  conf = 0.516, sup = 0.103
# {Saver} ---> {American Staffordshire Terrier, Stray, Terrier, Medium, Above-Average}:  conf = 0.212, sup = 0.103
# {Terrier} ---> {American Staffordshire Terrier, Stray, Saver, Medium, Above-Average}:  conf = 0.446, sup = 0.103
# {American Staffordshire Terrier} ---> {Stray, Terrier, Saver, Medium, Above-Average}:  conf = 0.651, sup = 0.103

# %%
df = pd.DataFrame(H, columns =['From', 'To', 'Confidence'])
df
# Out:
#                                          From  \
# 0                                     (Stray)
# 1                                      (Baby)
# 2                                      (Baby)
# 3                                      (True)
# 4                                      (Baby)
# ...                                       ...
# 1555  (American Staffordshire Terrier, Stray)
# 1556                          (Above-Average)
# 1557                                  (Saver)
# 1558                                (Terrier)
# 1559         (American Staffordshire Terrier)
#
#                                                      To  Confidence
# 0                                                (Baby)    0.229155
# 1                                               (Stray)    0.732207
# 2                                                (Male)    0.478627
# 3                                                (Baby)    0.273808
# 4                                                (True)    0.632120
# ...                                                 ...         ...
# 1555            (Above-Average, Terrier, Saver, Medium)    1.000000
# 1556  (American Staffordshire Terrier, Stray, Terrie...    0.515702
# 1557  (American Staffordshire Terrier, Stray, Terrie...    0.212321
# 1558  (American Staffordshire Terrier, Stray, Saver,...    0.446145
# 1559     (Stray, Terrier, Saver, Medium, Above-Average)    0.651421
#
# [1560 rows x 3 columns]

# %%
# calculate interest factors
interest_factors = np.zeros(len(H))
support = np.zeros(len(H))
for i in range(len(H)):
    a = support_data[H[i][0]]
    b = support_data[H[i][1]]
    c = support_data[H[i][0].union(H[i][1])]
    support[i] = round(c, 3)
    interest_factors[i] = round(c / (a * b), 3)
df['Support'] = support
df['Interest-Factor'] = interest_factors

# %%
# Filter the rules that result in True(IsAdopted)
df = df[df['To']=={'True'}]
df
# Out:
#                     From      To  Confidence  Support  Interest-Factor
# 4                 (Baby)  (True)    0.632120    0.135            1.284
# 12               (Young)  (True)    0.560307    0.161            1.138
# 24               (Adult)  (True)    0.423960    0.164            0.861
# 40             (Terrier)  (True)    0.454965    0.105            0.924
# 64               (Large)  (True)    0.541831    0.104            1.101
# 66              (Female)  (True)    0.514601    0.239            1.045
# 85              (Budget)  (True)    0.497325    0.155            1.010
# 87               (Stray)  (True)    0.492011    0.335            0.999
# 89           (Brightest)  (True)    0.540447    0.172            1.098
# 91              (Medium)  (True)    0.495178    0.257            1.006
# 135               (Male)  (True)    0.472937    0.254            0.961
# 137              (Saver)  (True)    0.490134    0.237            0.996
# 139              (Small)  (True)    0.453959    0.131            0.922
# 141              (Black)  (True)    0.514352    0.134            1.045
# 143            (Average)  (True)    0.527434    0.116            1.071
# 145    (Owner Surrender)  (True)    0.630257    0.140            1.280
# 243        (Baby, Stray)  (True)    0.640761    0.100            1.302
# 248       (Young, Stray)  (True)    0.558636    0.114            1.135
# 263       (Adult, Stray)  (True)    0.418614    0.106            0.850
# 325       (Saver, Stray)  (True)    0.488822    0.159            0.993
# 331     (Female, Medium)  (True)    0.523628    0.128            1.064
# 337      (Saver, Medium)  (True)    0.471903    0.117            0.959
# 343      (Saver, Female)  (True)    0.517151    0.117            1.051
# 414      (Stray, Female)  (True)    0.510543    0.161            1.037
# 543        (Male, Stray)  (True)    0.475964    0.174            0.967
# 555       (Male, Medium)  (True)    0.469706    0.128            0.954
# 561      (Stray, Medium)  (True)    0.494012    0.173            1.004
# 567  (Brightest, Medium)  (True)    0.540643    0.123            1.098
# 573   (Brightest, Stray)  (True)    0.534043    0.117            1.085
# 578      (Budget, Stray)  (True)    0.491348    0.107            0.998
# 583     (Budget, Medium)  (True)    0.525997    0.121            1.069
# 652        (Saver, Male)  (True)    0.466468    0.120            0.948

# %%
df.sort_values('Support', ascending=False).head(10)
# Out:
#                 From      To  Confidence  Support  Interest-Factor
# 87           (Stray)  (True)    0.492011    0.335            0.999
# 91          (Medium)  (True)    0.495178    0.257            1.006
# 135           (Male)  (True)    0.472937    0.254            0.961
# 66          (Female)  (True)    0.514601    0.239            1.045
# 137          (Saver)  (True)    0.490134    0.237            0.996
# 543    (Male, Stray)  (True)    0.475964    0.174            0.967
# 561  (Stray, Medium)  (True)    0.494012    0.173            1.004
# 89       (Brightest)  (True)    0.540447    0.172            1.098
# 24           (Adult)  (True)    0.423960    0.164            0.861
# 414  (Stray, Female)  (True)    0.510543    0.161            1.037

# %%
df.sort_values('Confidence', ascending=False).head(10)
# Out:
#                     From      To  Confidence  Support  Interest-Factor
# 243        (Baby, Stray)  (True)    0.640761    0.100            1.302
# 4                 (Baby)  (True)    0.632120    0.135            1.284
# 145    (Owner Surrender)  (True)    0.630257    0.140            1.280
# 12               (Young)  (True)    0.560307    0.161            1.138
# 248       (Young, Stray)  (True)    0.558636    0.114            1.135
# 64               (Large)  (True)    0.541831    0.104            1.101
# 567  (Brightest, Medium)  (True)    0.540643    0.123            1.098
# 89           (Brightest)  (True)    0.540447    0.172            1.098
# 573   (Brightest, Stray)  (True)    0.534043    0.117            1.085
# 143            (Average)  (True)    0.527434    0.116            1.071

# %%
df.sort_values('Interest-Factor', ascending=False).head(10)
# Out:
#                     From      To  Confidence  Support  Interest-Factor
# 243        (Baby, Stray)  (True)    0.640761    0.100            1.302
# 4                 (Baby)  (True)    0.632120    0.135            1.284
# 145    (Owner Surrender)  (True)    0.630257    0.140            1.280
# 12               (Young)  (True)    0.560307    0.161            1.138
# 248       (Young, Stray)  (True)    0.558636    0.114            1.135
# 64               (Large)  (True)    0.541831    0.104            1.101
# 567  (Brightest, Medium)  (True)    0.540643    0.123            1.098
# 89           (Brightest)  (True)    0.540447    0.172            1.098
# 573   (Brightest, Stray)  (True)    0.534043    0.117            1.085
# 143            (Average)  (True)    0.527434    0.116            1.071
