# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Read Animal Centor Intakes and Outcomes data

# %%
# Read intakes csv file
intakes = pd.read_csv('processed_data/dog_intakes_unified.csv', dtype={
    'AnimalID': 'string',
    'ID': 'string',
    'Breed': 'string',
    'Color': 'string',
    'Gender': 'category',
    'Name': 'string',
    'Intake-DateTime': 'string',
    'Intake-Type': 'string',
    'Intake-Condition': 'string',
    'Intake-Age(days)': 'int',
}, parse_dates=['Intake-DateTime'])
intakes.dtypes
# Out:
# AnimalID            string[python]
# ID                  string[python]
# Breed               string[python]
# Color               string[python]
# Gender                    category
# Name                string[python]
# Intake-DateTime     datetime64[ns]
# Intake-Type         string[python]
# Intake-Condition    string[python]
# Intake-Age(days)             int32
# dtype: object

# %%
intakes
# Out:
#       AnimalID         ID                           Breed           Color  \
# 0      A006100    A006100                Spinone Italiano          Yellow
# 1      A006100   A006100+                Spinone Italiano          Yellow
# 2      A006100  A006100++                Spinone Italiano          Yellow
# 3      A047759    A006101                       Dachshund        Tricolor
# 4      A134067    A134067               Shetland Sheepdog           Brown
# ...        ...        ...                             ...             ...
# 87059  A893570    A893570                      Rottweiler           Black
# 87060  A893573    A893573                  Border Terrier           Brown
# 87061  A893578    A893578  American Staffordshire Terrier  Yellow Brindle
# 87062  A893579    A893579  American Staffordshire Terrier           Black
# 87063  A893585    A893585                 German Shepherd           Black
#
#        Gender     Name     Intake-DateTime      Intake-Type Intake-Condition  \
# 0        Male    Scamp 2014-03-07 14:26:00    Public Assist           Normal
# 1        Male    Scamp 2014-12-19 10:21:00    Public Assist           Normal
# 2        Male    Scamp 2017-12-07 14:07:00            Stray           Normal
# 3        Male     Oreo 2014-04-02 15:55:00  Owner Surrender           Normal
# 4        Male   Bandit 2013-11-16 09:02:00    Public Assist          Injured
# ...       ...      ...                 ...              ...              ...
# 87059  Female     <NA> 2023-11-23 12:17:00            Stray           Normal
# 87060     NaN     <NA> 2023-11-23 13:45:00            Stray           Normal
# 87061    Male    Tiger 2023-11-23 20:19:00            Stray          Injured
# 87062    Male     <NA> 2023-11-23 21:00:00            Stray          Injured
# 87063    Male  Unknown 2023-11-23 20:19:00            Stray          Injured
#
#        Intake-Age(days)
# 0                  2190
# 1                  2555
# 2                  3650
# 3                  3650
# 4                 12190
# ...                 ...
# 87059               730
# 87060               730
# 87061               240
# 87062               730
# 87063                30
#
# [87064 rows x 10 columns]

# %%
# Read outcomes csv file
outcomes = pd.read_csv('processed_data/dog_outcomes_unified.csv', dtype={
    'AnimalID': 'string',
    'ID': 'string',
    'Breed': 'string',
    'Color': 'string',
    'Gender': 'category',
    'Name': 'string',
    'Date-Of-Birth': 'string',
    'Outcome-DateTime': 'string',
    'Outcome-Type': 'string',
    'Outcome-Subtype': 'string',
    'Outcome-Age(days)': 'int'
}, parse_dates=['Date-Of-Birth', 'Outcome-DateTime'])
outcomes.dtypes
# Out:
# AnimalID             string[python]
# ID                   string[python]
# Breed                string[python]
# Color                string[python]
# Gender                     category
# Name                 string[python]
# Date-Of-Birth        datetime64[ns]
# Outcome-DateTime     datetime64[ns]
# Outcome-Type         string[python]
# Outcome-Subtype      string[python]
# Outcome-Age(days)             int32
# dtype: object

# %%
outcomes
# Out:
#       AnimalID         ID               Breed     Color  Gender     Name  \
# 0      A006100    A006100    Spinone Italiano    Yellow    Male    Scamp
# 1      A006100   A006100+    Spinone Italiano    Yellow    Male    Scamp
# 2      A006100  A006100++    Spinone Italiano    Yellow    Male    Scamp
# 3      A047759    A047759           Dachshund  Tricolor    Male     Oreo
# 4      A134067    A134067   Shetland Sheepdog     Brown    Male   Bandit
# ...        ...        ...                 ...       ...     ...      ...
# 86974  A893431    A893431           Chihuahua  Tricolor  Female    Chili
# 86975  A893432    A893432           Chihuahua       Tan  Female     Coco
# 86976  A893452    A893452             Maltese     White  Female   Sophie
# 86977  A893529    A893529  Labrador Retriever     White  Female     <NA>
# 86978  A893585    A893585     German Shepherd     Black    Male  Unknown
#
#       Date-Of-Birth    Outcome-DateTime     Outcome-Type Outcome-Subtype  \
# 0        2007-07-09 2014-03-08 17:10:00  Return to Owner            <NA>
# 1        2007-07-09 2014-12-20 16:35:00  Return to Owner            <NA>
# 2        2007-07-09 2017-12-07 00:00:00  Return to Owner            <NA>
# 3        2004-04-02 2014-04-07 15:12:00         Transfer         Partner
# 4        1997-10-16 2013-11-16 11:54:00  Return to Owner            <NA>
# ...             ...                 ...              ...             ...
# 86974    2015-11-21 2023-11-21 15:41:00  Return to Owner            <NA>
# 86975    2015-11-21 2023-11-21 15:41:00  Return to Owner            <NA>
# 86976    2016-11-21 2023-11-22 11:26:00  Return to Owner            <NA>
# 86977    2023-09-22 2023-11-22 16:51:00         Transfer         Partner
# 86978    2023-09-24 2023-11-24 14:12:00         Transfer         Partner
#
#        Outcome-Age(days)
# 0                   2435
# 1                   2722
# 2                   3804
# 3                   3658
# 4                   5875
# ...                  ...
# 86974               2923
# 86975               2923
# 86976               2557
# 86977                 62
# 86978                 62
#
# [86979 rows x 11 columns]

# %% [markdown]
# ### Fill in missing values

# %%
# Fill in missing value in Name and Outcome-Subtype with Unknwon
intakes['Name'] = intakes['Name'].fillna('Unknown')
outcomes['Name'] = outcomes['Name'].fillna('Unknown')
outcomes['Outcome-Subtype'] = outcomes['Outcome-Subtype'].fillna('Unknown')
# Rrop rows that still have missing value
intakes = intakes.dropna().reset_index(drop=True)
outcomes = outcomes.dropna().reset_index(drop=True)

# %% [markdown]
# ### Remove Abnormal values

# %%
# Remove negative age values
intakes = intakes[intakes['Intake-Age(days)'] >= 0]
outcomes = outcomes[outcomes['Outcome-Age(days)'] >= 0]

# %%
intakes
# Out:
#       AnimalID         ID                           Breed           Color  \
# 0      A006100    A006100                Spinone Italiano          Yellow
# 1      A006100   A006100+                Spinone Italiano          Yellow
# 2      A006100  A006100++                Spinone Italiano          Yellow
# 3      A047759    A006101                       Dachshund        Tricolor
# 4      A134067    A134067               Shetland Sheepdog           Brown
# ...        ...        ...                             ...             ...
# 86402  A893565    A893565                       Chihuahua            Buff
# 86403  A893570    A893570                      Rottweiler           Black
# 86404  A893578    A893578  American Staffordshire Terrier  Yellow Brindle
# 86405  A893579    A893579  American Staffordshire Terrier           Black
# 86406  A893585    A893585                 German Shepherd           Black
#
#        Gender     Name     Intake-DateTime      Intake-Type Intake-Condition  \
# 0        Male    Scamp 2014-03-07 14:26:00    Public Assist           Normal
# 1        Male    Scamp 2014-12-19 10:21:00    Public Assist           Normal
# 2        Male    Scamp 2017-12-07 14:07:00            Stray           Normal
# 3        Male     Oreo 2014-04-02 15:55:00  Owner Surrender           Normal
# 4        Male   Bandit 2013-11-16 09:02:00    Public Assist          Injured
# ...       ...      ...                 ...              ...              ...
# 86402  Female  Unknown 2023-11-23 08:31:00            Stray          Injured
# 86403  Female  Unknown 2023-11-23 12:17:00            Stray           Normal
# 86404    Male    Tiger 2023-11-23 20:19:00            Stray          Injured
# 86405    Male  Unknown 2023-11-23 21:00:00            Stray          Injured
# 86406    Male  Unknown 2023-11-23 20:19:00            Stray          Injured
#
#        Intake-Age(days)
# 0                  2190
# 1                  2555
# 2                  3650
# 3                  3650
# 4                 12190
# ...                 ...
# 86402               365
# 86403               730
# 86404               240
# 86405               730
# 86406                30
#
# [86396 rows x 10 columns]

# %%
outcomes
# Out:
#       AnimalID         ID               Breed     Color  Gender     Name  \
# 0      A006100    A006100    Spinone Italiano    Yellow    Male    Scamp
# 1      A006100   A006100+    Spinone Italiano    Yellow    Male    Scamp
# 2      A006100  A006100++    Spinone Italiano    Yellow    Male    Scamp
# 3      A047759    A047759           Dachshund  Tricolor    Male     Oreo
# 4      A134067    A134067   Shetland Sheepdog     Brown    Male   Bandit
# ...        ...        ...                 ...       ...     ...      ...
# 86301  A893431    A893431           Chihuahua  Tricolor  Female    Chili
# 86302  A893432    A893432           Chihuahua       Tan  Female     Coco
# 86303  A893452    A893452             Maltese     White  Female   Sophie
# 86304  A893529    A893529  Labrador Retriever     White  Female  Unknown
# 86305  A893585    A893585     German Shepherd     Black    Male  Unknown
#
#       Date-Of-Birth    Outcome-DateTime     Outcome-Type Outcome-Subtype  \
# 0        2007-07-09 2014-03-08 17:10:00  Return to Owner         Unknown
# 1        2007-07-09 2014-12-20 16:35:00  Return to Owner         Unknown
# 2        2007-07-09 2017-12-07 00:00:00  Return to Owner         Unknown
# 3        2004-04-02 2014-04-07 15:12:00         Transfer         Partner
# 4        1997-10-16 2013-11-16 11:54:00  Return to Owner         Unknown
# ...             ...                 ...              ...             ...
# 86301    2015-11-21 2023-11-21 15:41:00  Return to Owner         Unknown
# 86302    2015-11-21 2023-11-21 15:41:00  Return to Owner         Unknown
# 86303    2016-11-21 2023-11-22 11:26:00  Return to Owner         Unknown
# 86304    2023-09-22 2023-11-22 16:51:00         Transfer         Partner
# 86305    2023-09-24 2023-11-24 14:12:00         Transfer         Partner
#
#        Outcome-Age(days)
# 0                   2435
# 1                   2722
# 2                   3804
# 3                   3658
# 4                   5875
# ...                  ...
# 86301               2923
# 86302               2923
# 86303               2557
# 86304                 62
# 86305                 62
#
# [86285 rows x 11 columns]

# %% [markdown]
# ### Add a new column of age category according to the outcomes age

# %%
conditions = [
    (outcomes['Outcome-Age(days)'] <= 180),
    (outcomes['Outcome-Age(days)'] > 180) & (outcomes['Outcome-Age(days)'] <= 730),
    (outcomes['Outcome-Age(days)'] > 730) & (outcomes['Outcome-Age(days)'] <= 2555),
    (outcomes['Outcome-Age(days)'] > 2555)
]
values = ['Baby', 'Young', 'Adult', 'Senior']

outcomes['Age'] = np.select(conditions, values)

# %% [markdown]
# ### Add a new boolean column 'IsAdopted' according to 'Outcome-type'

# %%
adopted = ['Return to Owner', 'Adoption', 'Rto-Adopt']
outcomes['IsAdopted'] = np.where(outcomes['Outcome-Type'].isin(adopted), True, False)

# %%
outcomes
# Out:
#       AnimalID         ID               Breed     Color  Gender     Name  \
# 0      A006100    A006100    Spinone Italiano    Yellow    Male    Scamp
# 1      A006100   A006100+    Spinone Italiano    Yellow    Male    Scamp
# 2      A006100  A006100++    Spinone Italiano    Yellow    Male    Scamp
# 3      A047759    A047759           Dachshund  Tricolor    Male     Oreo
# 4      A134067    A134067   Shetland Sheepdog     Brown    Male   Bandit
# ...        ...        ...                 ...       ...     ...      ...
# 86301  A893431    A893431           Chihuahua  Tricolor  Female    Chili
# 86302  A893432    A893432           Chihuahua       Tan  Female     Coco
# 86303  A893452    A893452             Maltese     White  Female   Sophie
# 86304  A893529    A893529  Labrador Retriever     White  Female  Unknown
# 86305  A893585    A893585     German Shepherd     Black    Male  Unknown
#
#       Date-Of-Birth    Outcome-DateTime     Outcome-Type Outcome-Subtype  \
# 0        2007-07-09 2014-03-08 17:10:00  Return to Owner         Unknown
# 1        2007-07-09 2014-12-20 16:35:00  Return to Owner         Unknown
# 2        2007-07-09 2017-12-07 00:00:00  Return to Owner         Unknown
# 3        2004-04-02 2014-04-07 15:12:00         Transfer         Partner
# 4        1997-10-16 2013-11-16 11:54:00  Return to Owner         Unknown
# ...             ...                 ...              ...             ...
# 86301    2015-11-21 2023-11-21 15:41:00  Return to Owner         Unknown
# 86302    2015-11-21 2023-11-21 15:41:00  Return to Owner         Unknown
# 86303    2016-11-21 2023-11-22 11:26:00  Return to Owner         Unknown
# 86304    2023-09-22 2023-11-22 16:51:00         Transfer         Partner
# 86305    2023-09-24 2023-11-24 14:12:00         Transfer         Partner
#
#        Outcome-Age(days)     Age  IsAdopted
# 0                   2435   Adult       True
# 1                   2722  Senior       True
# 2                   3804  Senior       True
# 3                   3658  Senior      False
# 4                   5875  Senior       True
# ...                  ...     ...        ...
# 86301               2923  Senior       True
# 86302               2923  Senior       True
# 86303               2557  Senior       True
# 86304                 62    Baby      False
# 86305                 62    Baby      False
#
# [86285 rows x 13 columns]

# %% [markdown]
# ### Merge intakes and outcomes dataframes by ID

# %%
intakes_outcomes = pd.merge(intakes, outcomes, how="inner", on=["AnimalID", "ID", "Breed", "Color", "Gender", "Name"], validate="1:1")
intakes_outcomes['Outcome-Age(days)'] = intakes_outcomes['Outcome-Age(days)'].astype('Int64')
intakes_outcomes
# Out:
#       AnimalID         ID               Breed     Color  Gender     Name  \
# 0      A006100    A006100    Spinone Italiano    Yellow    Male    Scamp
# 1      A006100   A006100+    Spinone Italiano    Yellow    Male    Scamp
# 2      A006100  A006100++    Spinone Italiano    Yellow    Male    Scamp
# 3      A134067    A134067   Shetland Sheepdog     Brown    Male   Bandit
# 4      A141142    A141142  Labrador Retriever     Black  Female   Bettie
# ...        ...        ...                 ...       ...     ...      ...
# 85791  A893431    A893431           Chihuahua  Tricolor  Female    Chili
# 85792  A893432    A893432           Chihuahua       Tan  Female     Coco
# 85793  A893452    A893452             Maltese     White  Female   Sophie
# 85794  A893529    A893529  Labrador Retriever     White  Female  Unknown
# 85795  A893585    A893585     German Shepherd     Black    Male  Unknown
#
#           Intake-DateTime      Intake-Type Intake-Condition  Intake-Age(days)  \
# 0     2014-03-07 14:26:00    Public Assist           Normal              2190
# 1     2014-12-19 10:21:00    Public Assist           Normal              2555
# 2     2017-12-07 14:07:00            Stray           Normal              3650
# 3     2013-11-16 09:02:00    Public Assist          Injured             12190
# 4     2013-11-16 14:46:00            Stray             Aged             11825
# ...                   ...              ...              ...               ...
# 85791 2023-11-21 11:21:00    Public Assist           Normal              2920
# 85792 2023-11-21 11:21:00    Public Assist           Normal              2920
# 85793 2023-11-21 13:38:00    Public Assist           Normal              2555
# 85794 2023-11-22 14:26:00  Owner Surrender           Normal                30
# 85795 2023-11-23 20:19:00            Stray          Injured                30
#
#       Date-Of-Birth    Outcome-DateTime     Outcome-Type Outcome-Subtype  \
# 0        2007-07-09 2014-03-08 17:10:00  Return to Owner         Unknown
# 1        2007-07-09 2014-12-20 16:35:00  Return to Owner         Unknown
# 2        2007-07-09 2017-12-07 00:00:00  Return to Owner         Unknown
# 3        1997-10-16 2013-11-16 11:54:00  Return to Owner         Unknown
# 4        1998-06-01 2013-11-17 11:40:00  Return to Owner         Unknown
# ...             ...                 ...              ...             ...
# 85791    2015-11-21 2023-11-21 15:41:00  Return to Owner         Unknown
# 85792    2015-11-21 2023-11-21 15:41:00  Return to Owner         Unknown
# 85793    2016-11-21 2023-11-22 11:26:00  Return to Owner         Unknown
# 85794    2023-09-22 2023-11-22 16:51:00         Transfer         Partner
# 85795    2023-09-24 2023-11-24 14:12:00         Transfer         Partner
#
#        Outcome-Age(days)     Age  IsAdopted
# 0                   2435   Adult       True
# 1                   2722  Senior       True
# 2                   3804  Senior       True
# 3                   5875  Senior       True
# 4                   5648  Senior       True
# ...                  ...     ...        ...
# 85791               2923  Senior       True
# 85792               2923  Senior       True
# 85793               2557  Senior       True
# 85794                 62    Baby      False
# 85795                 62    Baby      False
#
# [85796 rows x 17 columns]

# %% [markdown]
# ### Read dog breed data

# %%
breeds = pd.read_csv('processed_data/breed_data.csv', dtype={
    'Breed': 'string',
    'Category': 'category',
    'Intelligence-Ranking': 'Float64',
    'Intelligence-Category': 'category',
    'Size-Category': 'category',
    'Longevity': 'Float64',
    'Total-Cost($)': 'Float64',
    'Purchase-Cost($)': 'Float64',
    'Food-Cost($)': 'Float64'
})
breeds.dtypes
# Out:
# Breed                    string[python]
# Category                       category
# Intelligence-Ranking            Float64
# Intelligence-Category          category
# Size-Category                  category
# Longevity                       Float64
# Total-Cost($)                   Float64
# Purchase-Cost($)                Float64
# Food-Cost($)                    Float64
# dtype: object

# %%
breeds
# Out:
#                            Breed      Category  Intelligence-Ranking  \
# 0                  Affenpinscher           Toy                 37.00
# 1                   Afghan Hound         Hound                 80.00
# 2               Airedale Terrier       Terrier                 29.00
# 3                          Akita       Working                 54.00
# 4               Alaskan Malamute       Working                 50.00
# ..                           ...           ...                   ...
# 167                      Whippet         Hound                 51.00
# 168             Wire Fox Terrier       Terrier                 51.00
# 169  Wirehaired Pointing Griffon      Sporting                 46.00
# 170               Xoloitzcuintli  Non-Sporting                  <NA>
# 171            Yorkshire Terrier           Toy                 27.00
#
#     Intelligence-Category Size-Category  Longevity  Total-Cost($)  \
# 0           Above-Average         Small      11.42       15835.00
# 1                  Lowest         Large      11.92       20818.00
# 2           Above-Average        Medium      11.45           <NA>
# 3                 Average         Large      10.16       18217.00
# 4                 Average         Large      10.67       19069.00
# ..                    ...           ...        ...            ...
# 167               Average        Medium      12.87       18160.00
# 168               Average         Small      13.17           <NA>
# 169               Average        Medium       8.80           <NA>
# 170                   NaN        Medium       <NA>           <NA>
# 171         Above-Average         Small      12.60       17944.00
#
#      Purchase-Cost($)  Food-Cost($)
# 0              510.00       3180.00
# 1              890.00       7260.00
# 2              733.00          <NA>
# 3             1202.00       6188.00
# 4             1210.00       6499.00
# ..                ...           ...
# 167            915.00       3584.00
# 168            668.00          <NA>
# 169            755.00          <NA>
# 170            717.00          <NA>
# 171           1057.00       3508.00
#
# [172 rows x 9 columns]

# %% [markdown]
# ### Fill in missing values

# %%
# Fill in missing values in Intelligence-Ranking and Longevity with the average value of the same category
breeds["Intelligence-Ranking"].fillna(
    breeds.groupby("Category")["Intelligence-Ranking"].transform("mean"),inplace=True
)
breeds["Intelligence-Ranking"].fillna(
    breeds["Intelligence-Ranking"].mean(),inplace=True
)

breeds["Longevity"].fillna(
    breeds.groupby("Category")["Longevity"].transform("mean"),inplace=True
)
breeds["Longevity"].fillna(
    breeds["Longevity"].mean(),inplace=True
)

# %%
# Fill in numeric missing values in Cost with average value of the same category & size combination
breeds["Total-Cost($)"].fillna(
    breeds.groupby(["Category", "Size-Category"])["Total-Cost($)"].transform("mean"),inplace=True
)
breeds["Total-Cost($)"].fillna(
    breeds["Total-Cost($)"].mean(),inplace=True
)

breeds["Food-Cost($)"].fillna(
    breeds.groupby(["Category", "Size-Category"])["Food-Cost($)"].transform("mean"),inplace=True
)
breeds["Food-Cost($)"].fillna(
    breeds["Food-Cost($)"].mean(),inplace=True
)

breeds["Purchase-Cost($)"].fillna(
    breeds.groupby(["Category", "Longevity", "Size-Category"])["Purchase-Cost($)"].transform("mean"),inplace=True
)
breeds["Purchase-Cost($)"].fillna(
    breeds["Purchase-Cost($)"].mean(),inplace=True
)

breeds
# Out:
#                            Breed      Category  Intelligence-Ranking  \
# 0                  Affenpinscher           Toy                 37.00
# 1                   Afghan Hound         Hound                 80.00
# 2               Airedale Terrier       Terrier                 29.00
# 3                          Akita       Working                 54.00
# 4               Alaskan Malamute       Working                 50.00
# ..                           ...           ...                   ...
# 167                      Whippet         Hound                 51.00
# 168             Wire Fox Terrier       Terrier                 51.00
# 169  Wirehaired Pointing Griffon      Sporting                 46.00
# 170               Xoloitzcuintli  Non-Sporting                 46.71
# 171            Yorkshire Terrier           Toy                 27.00
#
#     Intelligence-Category Size-Category  Longevity  Total-Cost($)  \
# 0           Above-Average         Small      11.42       15835.00
# 1                  Lowest         Large      11.92       20818.00
# 2           Above-Average        Medium      11.45       16605.67
# 3                 Average         Large      10.16       18217.00
# 4                 Average         Large      10.67       19069.00
# ..                    ...           ...        ...            ...
# 167               Average        Medium      12.87       18160.00
# 168               Average         Small      13.17       18078.44
# 169               Average        Medium       8.80       16668.89
# 170                   NaN        Medium      10.98       15294.33
# 171         Above-Average         Small      12.60       17944.00
#
#      Purchase-Cost($)  Food-Cost($)
# 0              510.00       3180.00
# 1              890.00       7260.00
# 2              733.00       4224.00
# 3             1202.00       6188.00
# 4             1210.00       6499.00
# ..                ...           ...
# 167            915.00       3584.00
# 168            668.00       3809.00
# 169            755.00       4219.45
# 170            717.00       3790.29
# 171           1057.00       3508.00
#
# [172 rows x 9 columns]

# %%
# Cast object numbers to float
pd.options.display.float_format = "{:.2f}".format
breeds["Longevity"] = breeds["Longevity"].astype('float')
# Cast object numbers to int
breeds["Intelligence-Ranking"] = breeds["Intelligence-Ranking"].astype('int')
breeds["Total-Cost($)"] = breeds["Total-Cost($)"].astype('int')
breeds["Purchase-Cost($)"] = breeds["Purchase-Cost($)"].astype('int')
breeds["Food-Cost($)"] = breeds["Food-Cost($)"].astype('int')
breeds.dtypes
# Out:
# Breed                    string[python]
# Category                       category
# Intelligence-Ranking              int32
# Intelligence-Category          category
# Size-Category                  category
# Longevity                       float64
# Total-Cost($)                     int32
# Purchase-Cost($)                  int32
# Food-Cost($)                      int32
# dtype: object

# %%
# Fill in missing values in Intelligence-Category according to Intelligence-Ranking
intel_conditions = [
    (breeds['Intelligence-Ranking'] <= 10),
    (breeds['Intelligence-Ranking'] > 10) & (breeds['Intelligence-Ranking'] <= 26),
    (breeds['Intelligence-Ranking'] > 26) & (breeds['Intelligence-Ranking'] <= 39),
    (breeds['Intelligence-Ranking'] > 39) & (breeds['Intelligence-Ranking'] <= 54),
    (breeds['Intelligence-Ranking'] > 54) & (breeds['Intelligence-Ranking'] <= 69),
    (breeds['Intelligence-Ranking'] > 69)
]
intel_values = ['Brightest', 'Excellent', 'Above-Average', 'Average', 'Fair', 'Low']
breeds['Intelligence-Category'] = np.select(intel_conditions, intel_values)

breeds
# Out:
#                            Breed      Category  Intelligence-Ranking  \
# 0                  Affenpinscher           Toy                    37
# 1                   Afghan Hound         Hound                    80
# 2               Airedale Terrier       Terrier                    29
# 3                          Akita       Working                    54
# 4               Alaskan Malamute       Working                    50
# ..                           ...           ...                   ...
# 167                      Whippet         Hound                    51
# 168             Wire Fox Terrier       Terrier                    51
# 169  Wirehaired Pointing Griffon      Sporting                    46
# 170               Xoloitzcuintli  Non-Sporting                    46
# 171            Yorkshire Terrier           Toy                    27
#
#     Intelligence-Category Size-Category  Longevity  Total-Cost($)  \
# 0           Above-Average         Small      11.42          15835
# 1                     Low         Large      11.92          20818
# 2           Above-Average        Medium      11.45          16605
# 3                 Average         Large      10.16          18217
# 4                 Average         Large      10.67          19069
# ..                    ...           ...        ...            ...
# 167               Average        Medium      12.87          18160
# 168               Average         Small      13.17          18078
# 169               Average        Medium       8.80          16668
# 170               Average        Medium      10.98          15294
# 171         Above-Average         Small      12.60          17944
#
#      Purchase-Cost($)  Food-Cost($)
# 0                 510          3180
# 1                 890          7260
# 2                 733          4224
# 3                1202          6188
# 4                1210          6499
# ..                ...           ...
# 167               915          3584
# 168               668          3809
# 169               755          4219
# 170               717          3790
# 171              1057          3508
#
# [172 rows x 9 columns]

# %% [markdown]
# ### Join breed data to intakes & outcomes data

# %%
data = pd.merge(intakes_outcomes, breeds, how="left", on=["Breed"])
data
# Out:
#       AnimalID         ID               Breed     Color  Gender     Name  \
# 0      A006100    A006100    Spinone Italiano    Yellow    Male    Scamp
# 1      A006100   A006100+    Spinone Italiano    Yellow    Male    Scamp
# 2      A006100  A006100++    Spinone Italiano    Yellow    Male    Scamp
# 3      A134067    A134067   Shetland Sheepdog     Brown    Male   Bandit
# 4      A141142    A141142  Labrador Retriever     Black  Female   Bettie
# ...        ...        ...                 ...       ...     ...      ...
# 85791  A893431    A893431           Chihuahua  Tricolor  Female    Chili
# 85792  A893432    A893432           Chihuahua       Tan  Female     Coco
# 85793  A893452    A893452             Maltese     White  Female   Sophie
# 85794  A893529    A893529  Labrador Retriever     White  Female  Unknown
# 85795  A893585    A893585     German Shepherd     Black    Male  Unknown
#
#           Intake-DateTime      Intake-Type Intake-Condition  Intake-Age(days)  \
# 0     2014-03-07 14:26:00    Public Assist           Normal              2190
# 1     2014-12-19 10:21:00    Public Assist           Normal              2555
# 2     2017-12-07 14:07:00            Stray           Normal              3650
# 3     2013-11-16 09:02:00    Public Assist          Injured             12190
# 4     2013-11-16 14:46:00            Stray             Aged             11825
# ...                   ...              ...              ...               ...
# 85791 2023-11-21 11:21:00    Public Assist           Normal              2920
# 85792 2023-11-21 11:21:00    Public Assist           Normal              2920
# 85793 2023-11-21 13:38:00    Public Assist           Normal              2555
# 85794 2023-11-22 14:26:00  Owner Surrender           Normal                30
# 85795 2023-11-23 20:19:00            Stray          Injured                30
#
#        ...     Age IsAdopted  Category Intelligence-Ranking  \
# 0      ...   Adult      True  Sporting                   27
# 1      ...  Senior      True  Sporting                   27
# 2      ...  Senior      True  Sporting                   27
# 3      ...  Senior      True   Herding                    6
# 4      ...  Senior      True  Sporting                    7
# ...    ...     ...       ...       ...                  ...
# 85791  ...  Senior      True       Toy                   67
# 85792  ...  Senior      True       Toy                   67
# 85793  ...  Senior      True       Toy                   59
# 85794  ...    Baby     False  Sporting                    7
# 85795  ...    Baby     False   Herding                    3
#
#        Intelligence-Category Size-Category  Longevity Total-Cost($)  \
# 0              Above-Average         Large       9.00         18062
# 1              Above-Average         Large       9.00         18062
# 2              Above-Average         Large       9.00         18062
# 3                  Brightest         Small      12.53         17469
# 4                  Brightest        Medium      12.04         18422
# ...                      ...           ...        ...           ...
# 85791                   Fair         Small      16.50         22640
# 85792                   Fair         Small      16.50         22640
# 85793                   Fair         Small      12.25         16073
# 85794              Brightest        Medium      12.04         18422
# 85795              Brightest         Large       9.73         15091
#
#        Purchase-Cost($) Food-Cost($)
# 0                  1725         5679
# 1                  1725         5679
# 2                  1725         5679
# 3                   465         3698
# 4                   810         4819
# ...                 ...          ...
# 85791               588         4594
# 85792               588         4594
# 85793               650         2410
# 85794               810         4819
# 85795               820         3895
#
# [85796 rows x 25 columns]

# %% [markdown]
# ### Read active dogs data from petfinder

# %%
petfinder = pd.read_csv('processed_data/petfinder_unified.csv', dtype={
    'Petfinder-ID': 'string',
    'Name': 'string',
    'Size': 'category',
    'Gender': 'category',
    'Age': 'category',
    'Color': 'string',
    'Breed': 'string'
})
petfinder.dtypes
# Out:
# Petfinder-ID    string[python]
# Name            string[python]
# Size                  category
# Gender                category
# Age                   category
# Color           string[python]
# Breed           string[python]
# dtype: object

# %%
# Drop rows that have a missing value
petfinder = petfinder.dropna().reset_index(drop=True)

# %%
petfinder
# Out:
#      Petfinder-ID                                              Name  \
# 0        65653819                                            Eloise
# 1        68926034                                             Penny
# 2        69313950                                           Pirate
# 3        69340682                                             Fiona
# 4        69402276                                              Rory
# ...           ...                                               ...
# 7334     69816070                                 Bubba and Cadence
# 7335     69816083                                             Bubba
# 7336     69816084  NORA - 3 mo. old gentle quiet smart curious baby
# 7337     69816100                                             Blaze
# 7338     69816108                                             Molly
#
#              Size  Gender     Age     Color                           Breed
# 0           Large  Female   Adult      Gray                    Bull Terrier
# 1          Medium  Female    Baby     Black              Labrador Retriever
# 2     Extra Large    Male    Baby  Tricolor                   Saint Bernard
# 3           Small  Female  Senior   Apricot                       Chihuahua
# 4          Medium  Female   Adult       Red            Pembroke Welsh Corgi
# ...           ...     ...     ...       ...                             ...
# 7334        Small    Male  Senior  Tricolor                  Border Terrier
# 7335        Large    Male   Young     Black          Parson Russell Terrier
# 7336        Large  Female    Baby    Yellow              Labrador Retriever
# 7337       Medium    Male    Baby     Black  American Staffordshire Terrier
# 7338       Medium  Female    Baby       Red           Australian Cattle Dog
#
# [7339 rows x 7 columns]

# %% [markdown]
# ### Join breed data to petfinder dog data

# %%
petfinder = pd.merge(petfinder, breeds, how="left", on=["Breed"])
petfinder
# Out:
#      Petfinder-ID                                              Name  \
# 0        65653819                                            Eloise
# 1        68926034                                             Penny
# 2        69313950                                           Pirate
# 3        69340682                                             Fiona
# 4        69402276                                              Rory
# ...           ...                                               ...
# 7334     69816070                                 Bubba and Cadence
# 7335     69816083                                             Bubba
# 7336     69816084  NORA - 3 mo. old gentle quiet smart curious baby
# 7337     69816100                                             Blaze
# 7338     69816108                                             Molly
#
#              Size  Gender     Age     Color                           Breed  \
# 0           Large  Female   Adult      Gray                    Bull Terrier
# 1          Medium  Female    Baby     Black              Labrador Retriever
# 2     Extra Large    Male    Baby  Tricolor                   Saint Bernard
# 3           Small  Female  Senior   Apricot                       Chihuahua
# 4          Medium  Female   Adult       Red            Pembroke Welsh Corgi
# ...           ...     ...     ...       ...                             ...
# 7334        Small    Male  Senior  Tricolor                  Border Terrier
# 7335        Large    Male   Young     Black          Parson Russell Terrier
# 7336        Large  Female    Baby    Yellow              Labrador Retriever
# 7337       Medium    Male    Baby     Black  American Staffordshire Terrier
# 7338       Medium  Female    Baby       Red           Australian Cattle Dog
#
#       Category  Intelligence-Ranking Intelligence-Category Size-Category  \
# 0      Terrier                    66                  Fair        Medium
# 1     Sporting                     7             Brightest        Medium
# 2      Working                    65                  Fair         Large
# 3          Toy                    67                  Fair         Small
# 4      Herding                    11             Excellent         Small
# ...        ...                   ...                   ...           ...
# 7334   Terrier                    30         Above-Average         Small
# 7335   Terrier                    44               Average         Small
# 7336  Sporting                     7             Brightest        Medium
# 7337   Terrier                    34         Above-Average        Medium
# 7338   Herding                    10             Brightest        Medium
#
#       Longevity  Total-Cost($)  Purchase-Cost($)  Food-Cost($)
# 0         10.21          16051              1085          4087
# 1         12.04          18422               810          4819
# 2          7.78          17336               875          8124
# 3         16.50          22640               588          4594
# 4         12.25          19625               587          6026
# ...         ...            ...               ...           ...
# 7334      14.00          19575               833          3898
# 7335      11.48          18078               528          3809
# 7336      12.04          18422               810          4819
# 7337      11.48          16605              1043          4224
# 7338      11.67          17607               530          4671
#
# [7339 rows x 15 columns]

# %% [markdown]
# ### Write the processed data to csv file

# %%
data.to_csv('data.csv', index=False)
petfinder.to_csv('petfinder.csv', index=False)
